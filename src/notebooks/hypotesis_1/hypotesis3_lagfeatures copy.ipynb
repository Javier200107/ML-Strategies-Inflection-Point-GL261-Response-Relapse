# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, roc_curve, auc
import xgboost as xgb 
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from src.processing import Processing
import config
from sklearn.feature_selection import SelectKBest, chi2
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import pandas as pd
import numpy as np
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
import warnings
from src.datasplitting import DataSplitting
warnings.filterwarnings('ignore')
from sklearn.model_selection import GridSearchCV, PredefinedSplit, TimeSeriesSplit
from sklearn.metrics import (
    accuracy_score, f1_score, precision_score, recall_score,
    confusion_matrix, roc_auc_score, precision_recall_curve, auc, classification_report
)
from sklearn.impute import SimpleImputer

from src.processing import Processing
from sklearn.metrics import roc_curve, precision_recall_curve, average_precision_score
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import xgboost as xgb
from scipy.stats import linregress

from imblearn.over_sampling import SMOTE
from collections import Counter
from src.balance import split_data_nested_cv_ts, split_data, drop_mice_group, balance_classes_by_undersampling, balance_classes_by_undersampling_features_and_target, balance_before_merge, oversample_and_merge, ensemble_sample_and_merge

# %%
# Step 1: Load and preprocess the data
dataclass = Processing(source_path=config.RADIOMICS_FINAL_FEATURES, all_features=False)
dataclass.read()
# df = dataclass.preprocess()  # Assume this keeps mouse IDs for splitting
df = dataclass.df
DS_LENGTH = len(df)

df_sorted = df.sort_values(by=["m_id", "day_of_study"])

# Lista de características radiómicas
features = [col for col in df.columns if col not in ["group_name", "m_id", "day_of_study"]]

# # Calcular diferencias entre días (delta features)
# for feat in features:
#     print(df_sorted.groupby("m_id")[feat].diff().fillna(0))
#     df_sorted[f"delta_{feat}"] = df_sorted.groupby("m_id")[feat].diff().fillna(0)

# # # Calcular media y varianza acumuladas (rolling statistics)
# # for feat in features:
# #     df_sorted[f"{feat}_mean"] = df_sorted.groupby("m_id")[feat].expanding().mean().reset_index(level=0, drop=True)
# #     df_sorted[f"{feat}_var"] = df_sorted.groupby("m_id")[feat].expanding().var().fillna(0).reset_index(level=0, drop=True)

# # Función para calcular la pendiente (slope) de una feature con respecto al tiempo
# def compute_slope(x, y):
#     if len(x) < 2 or len(set(x)) == 1:  # Si hay menos de 2 valores distintos de x, no se puede calcular la pendiente
#         return 0
#     try:
#         slope, _, _, _, _ = linregress(x, y)
#         return slope
#     except ValueError as e:
#         print(f"⚠️ Error en linregress con x={x.tolist()} y={y.tolist()}: {e}")
#         return 0  # Devolvemos 0 en caso de error


# # Calcular pendiente para cada ratón y cada feature
# for feat in features:
#     df_sorted[f"slope_{feat}"] = df_sorted.groupby("m_id").apply(
#         lambda g: g["day_of_study"].rolling(window=len(g), min_periods=2)
#         .apply(lambda x: compute_slope(x, g.loc[x.index, feat]), raw=False)
#     ).reset_index(level=0, drop=True)

# # Guardar el dataset con las nuevas features
# df_sorted.to_csv("datos_con_lag_features_1.csv", index=False)
# Out:
# WARNING:root:Columns ['i', 'n', 'p', 'u', 't', '\\', 'f', 'e', 'a', 't', 'u', 'r', 'e', 's', '\\', 'r', 'a', 'd', 'i', 'o', 'm', 'i', 'c', 's', '_', 'f', 'i', 'n', 'a', 'l', '_', 'f', 'e', 'a', 't', 'u', 'r', 'e', 's', '_', 'n', 'o', '_', 'f', 'i', 'l', 't', 'e', 'r', 's', '.', 'c', 's', 'v'] are not in the dataset

# %%
import pandas as pd
import numpy as np
from scipy.stats import linregress

# Supongamos que df ya está cargado y tiene las columnas adecuadas
features = [col for col in df.columns if col not in ['group_name', 'm_id', 'day_of_study']]

# 1️⃣ Diferencia cada 2 días (delta_2)
# for feat in features:
#     df[f"delta_2_{feat}"] = df.groupby("m_id")[feat].diff(periods=2).fillna(0)

# # 2️⃣ Media móvil de 3 días (rolling_mean_3)
# for feat in features:
#     df[f"rolling_mean_3_{feat}"] = (
#         df.groupby("m_id")[feat]
#         .rolling(window=3, min_periods=1)
#         .mean()
#         .reset_index(level=0, drop=True)
#     )

# # 3️⃣ Varianza móvil de 3 días (rolling_var_3)
# for feat in features:
#     df[f"rolling_var_3_{feat}"] = (
#         df.groupby("m_id")[feat]
#         .rolling(window=3, min_periods=2)
#         .var()
#         .fillna(0)
#         .reset_index(level=0, drop=True)
#     )
#     df[f"{feat}_lag_1"] = df.groupby("m_id")[feat].shift(1)
#     df[f"{feat}_lag_3"] = df.groupby("m_id")[feat].shift(3)

# # 4️⃣ Mediana móvil de 3 días (rolling_median_3)
# for feat in features:
#     df[f"rolling_median_3_{feat}"] = (
#         df.groupby("m_id")[feat]
#         .rolling(window=3, min_periods=1)
#         .median()
#         .reset_index(level=0, drop=True)
#     )

# # 5️⃣ Momentum de 3 días (momentum_3)
# for feat in features:
#     df[f"momentum_3_{feat}"] = df[feat] - df.groupby("m_id")[feat].shift(3)

# # 6️⃣ Pendiente en los últimos 5 y 3 días (slope_5 y slope_3)
# def compute_slope(x, y):
#     if len(x) < 2 or len(set(x)) == 1:  # Si hay menos de 2 días distintos, la pendiente es 0
#         return 0
#     slope, _, _, _, _ = linregress(x, y)
#     return slope

# for feat in features:
#     df[f"slope_5_{feat}"] = (
#         df.groupby("m_id").apply(
#             lambda g: g["day_of_study"].rolling(window=5, min_periods=2)
#             .apply(lambda x: compute_slope(x, g.loc[x.index, feat]), raw=False)
#         ).reset_index(level=0, drop=True)
#     )
#     df[f"slope_3_{feat}"] = (
#         df.groupby("m_id").apply(
#             lambda g: g["day_of_study"].rolling(window=3, min_periods=2)
#             .apply(lambda x: compute_slope(x, g.loc[x.index, feat]), raw=False)
#         ).reset_index(level=0, drop=True)
#     )

# Save the new dataset
# df.to_csv("datos_con_lag_features_2.csv", index=False)
# df = pd.read_csv("datos_con_lag_features_2.csv")

# %%
# # Crear features temporales por ratón
# feature_deltas = []
# for mouse in df["m_id"].unique():
#     mouse_data = df_sorted[df_sorted["m_id"] == mouse].copy()
    
#     # Agregar diferencias entre días
#     for feat in features:
#         mouse_data[f"delta_{feat}"] = mouse_data[feat].diff().fillna(0)
    
#     # Agregar estadísticas agregadas
#     for feat in features:
#         mouse_data[f"{feat}_mean"] = mouse_data[feat].expanding().mean()
#         mouse_data[f"{feat}_var"] = mouse_data[feat].expanding().var().fillna(0)
    
#     feature_deltas.append(mouse_data)

# df_features = pd.concat(feature_deltas)

# # Seleccionar última observación de cada ratón como input
# df_last = df_features.groupby("m_id").last().reset_index()

# %%
# df_last

# %%
# df = pd.read_csv("datos_con_lag_features_1.csv")
# df.head()

# %%
# import neuroHarmonize
# from neuroHarmonize import harmonizationLearn, harmonizationApply  # ComBat
# from scipy.stats import spearmanr, mannwhitneyu
# # Lista de características radiómicas
# features = [col for col in df.columns if col not in ["group_name", "m_id", "day_of_study"]]
# print(f"🔹 Features originales: {len(features)}")

# # # 1️⃣ **Aplicar ComBat para armonización de features**
# # protocols = pd.DataFrame({"SITE": df["m_id"]})  # Convertir a DataFrame con columna SITE
# # features_matrix = df[features].values  # Matriz de features

# # # Aprender parámetros de ComBat
# # combat_params, stand_mean, var_pooled = harmonizationLearn(features_matrix, protocols)

# # # Aplicar transformación ComBat
# # features_harmonized = harmonizationApply(features_matrix, protocols, combat_params)
# # # Sustituir features originales por las armonizadas
# # df[features] = features_harmonized

# # 2️⃣ **Eliminar features con varianza < 0.01**
# variances = df[features].var()
# low_variance_features = variances[variances < 0.01].index.tolist()
# df.drop(columns=low_variance_features, inplace=True)
# m_features = [f for f in features if f not in low_variance_features]  # Actualizar lista de features

# # 3️⃣ **Eliminar features altamente correlacionadas (Spearman |𝜌| > 0.9)**
# corr_matrix = df[m_features].corr(method="spearman").abs()
# high_corr_features = set()

# for i in range(len(m_features)):
#     for j in range(i + 1, len(m_features)):
#         if corr_matrix.iloc[i, j] > 0.9:
#             high_corr_features.add(m_features[j])  # Eliminar una de las dos features correlacionadas

# df.drop(columns=list(high_corr_features), inplace=True)
# m_features = [f for f in m_features if f not in high_corr_features]

# # # 4️⃣ **Seleccionar features con Mann-Whitney U Test (p < 0.05)**
# # significant_features = []

# # for feat in features:
# #     group_0 = df[df["group_name"] == 0][feat]
# #     group_1 = df[df["group_name"] == 1][feat]
    
# #     _, p_value = mannwhitneyu(group_0, group_1, alternative="two-sided")
    
# #     if p_value < 0.05:
# #         significant_features.append(feat)

# # Guardar dataset con las features seleccionadas
# # df_selected = df[["group_name", "m_id", "day_of_study"] + significant_features]
# df.to_csv("datos_filtrados.csv", index=False)

# print(f"✅ Features preprocesadas y seleccionadas. Archivo guardado como 'datos_filtrados.csv'.")
# print(f"🔹 Features originales: {len(features)} → 🔹 Features finales: {len(m_features)}")

# %%
N_SPLITS = 5
TEST_SIZE = 0.3 
SEED = 42
SAMPLE_SIZE = 10
TOP_FEATURES = 15
SPLIT_METHOD = 'grouped_combinations_split_with_sampling'

# Hyperparameter grid for XGBClassifier
PARAM_GRID = {
    'xgbclassifier__n_estimators': [100, 500, 1000],
    'xgbclassifier__learning_rate': [0.01, 0.05, 0.1],
    'xgbclassifier__max_depth': [3, 4, 5, 7],
    'xgbclassifier__subsample': [0.6, 0.7, 0.8, 1.0],
    'xgbclassifier__min_child_weight': [1, 5, 10],
    'xgbclassifier__gamma': [0.5, 1, 1.5, 2, 5],
    'xgbclassifier__colsample_bytree': [0.6, 0.8, 1.0]
}
xgb_params = {
    'xgbclassifier__colsample_bytree': 0.6,
    'xgbclassifier__gamma': 0.5,
    'xgbclassifier__learning_rate': 0.01,
    'xgbclassifier__max_depth': 3,
    'xgbclassifier__min_child_weight': 1,
    'xgbclassifier__n_estimators': 100,
    'xgbclassifier__subsample': 0.6
}
OUTPUT_DIR = 'output_now_today'

# %%
def train_test_and_show_results(split_method: str, m_data: dict, plot_feature_importances_per_fold: bool = True, plot_roc_and_feature_importances: bool = True, show_fold_results: bool = True,
                                tune_hyperparameters: bool = False, param_grid: dict = None, xgb_params: dict = None, show_label: bool = True):

    # Track results for each fold
    fold_accuracies, fold_f1_macros, fold_precisions, fold_recalls, fold_roc_aucs, fold_f1_micros, fold_f1_weighted, feature_importances, true_positives, false_positives, true_negatives, false_negatives  = [], [], [], [], [], [], [], [], [], [], [], []

    best_params_per_fold = []  # Track best parameters per fold

    # Store ROC curve points for all folds
    roc_curves = []

    for fold, split_data in m_data.items():
        print(f"\nFold {fold}:")
        print(f"Original train class distribution: {Counter(split_data['y_train'])}")
        print(f"Original test class distribution: {Counter(split_data['y_test'])}") 
        
        # Check if directory exists
        if not os.path.exists(f"{OUTPUT_DIR}/{split_method}/fold_{fold}"):
            os.makedirs(f"{OUTPUT_DIR}/{split_method}/fold_{fold}")

        # Keep `m_id` for analysis later
        m_id_test = split_data['X_test']['m_id']  # Save `m_id` for test
        day_of_study_test = split_data['X_test']['day_of_study']  # Save `day_of_study` for test

        # Check that train ids are not in test
        train_ids = split_data['X_train']['m_id'].unique()
        test_ids = split_data['X_test']['m_id'].unique()
        
        print(f"Train IDs: {train_ids}")
        print(f"Test IDs: {test_ids}")

        # Exclude `m_id` and `day_of_study` for training
        X_train = split_data['X_train'].drop(columns=['m_id', 'day_of_study'])
        X_test = split_data['X_test'].drop(columns=['m_id', 'day_of_study'])

        # Get feature names
        feature_names = X_train.columns.str.replace('original_', '', regex=False)
        from sklearn.feature_selection import SelectFromModel

        if tune_hyperparameters:

            # Define the model with hyperparameter tuning
            model = Pipeline([
                ('imputer', SimpleImputer(strategy='mean')),  # Rellena NaN con la media de la columna
                ('scaler', StandardScaler()), 
                ('smote', SMOTE(k_neighbors=5, random_state=SEED)),
                # ('feature_selection', SelectFromModel(xgb.XGBClassifier(random_state=SEED), threshold="median")),  # Multivariate feature selection

                ('xgbclassifier', xgb.XGBClassifier(random_state=SEED))
            ])

            grid_search = GridSearchCV(model, param_grid=param_grid, cv=TimeSeriesSplit(n_splits=5), scoring='f1_macro', n_jobs=-1)
            grid_search.fit(X_train, split_data['y_train'])
            best_model = grid_search.best_estimator_
            best_params = grid_search.best_params_
            best_params_per_fold.append(best_params)  # Save best parameters
            print(f"Best parameters for fold {fold}: {best_params}")
        else:
            # Use provided xgb_params or default parameters if not tuning
            model = Pipeline([
                ('imputer', SimpleImputer(strategy='mean')),  # Rellena NaN con la media de la columna
                ('scaler', StandardScaler()), 
                ('smote', SMOTE(k_neighbors=5, random_state=SEED)),
                # ('feature_selection', SelectFromModel(xgb.XGBClassifier(random_state=SEED), threshold="median")),  # Multivariate feature selection

                ('xgbclassifier', xgb.XGBClassifier(**(xgb_params or {}), random_state=SEED)),
            ])
            
            model.fit(X_train, split_data['y_train'])
            best_model = model        

        # Extract feature importances from XGBoost
        xgb_model = best_model.named_steps['xgbclassifier']
        importances = xgb_model.feature_importances_

        # Evaluate on the test set
        preds = best_model.predict(X_test)
        preds_proba = best_model.predict_proba(X_test)[:, 1]  # Probability for the positive class
        
        # Calculate metrics
        accuracy = accuracy_score(split_data['y_test'], preds)
        f1_macro = f1_score(split_data['y_test'], preds, average='macro')
        f1_micro = f1_score(split_data['y_test'], preds, average='micro')
        f1_weighted = f1_score(split_data['y_test'], preds, average='weighted')
        precision = precision_score(split_data['y_test'], preds,zero_division=1)
        recall = recall_score(split_data['y_test'], preds, zero_division=1)

        fpr, tpr, _ = roc_curve(split_data['y_test'], preds_proba, pos_label=1)
        roc_auc = auc(fpr, tpr)

        # If auc is NaN and precision or recall is 1, set auc to 1, else set to 0
        if np.isnan(roc_auc) and (precision == 1 or recall == 1):
            roc_auc = 1
        elif np.isnan(roc_auc):
            roc_auc = 0
                
        roc_curves.append((fpr, tpr))

        # Calculate the confusion matrix
        cm = confusion_matrix(split_data['y_test'], preds)

        # Handle cases where the confusion matrix shape is unexpected
        if cm.shape == (1, 1):  # Only one class present
            tn, fp, fn, tp = (cm[0, 0], 0, 0, 0) if split_data['y_test'].iloc[0] == 0 else (0, 0, 0, cm[0, 0])
        elif cm.shape == (1, 2):  # One class is missing in y_test
            tn, fp, fn, tp = (cm[0, 0], cm[0, 1], 0, 0)
        elif cm.shape == (2, 1):  # One class is missing in preds
            tn, fp, fn, tp = (0, 0, cm[1, 0], cm[0, 0])
        else:  # Normal case with both classes present
            tn  , fp, fn, tp = cm.ravel()

         # Identify misclassified instances
        misclassified_mask = split_data['y_test'] != preds
        misclassified = pd.DataFrame({
            'm_id': m_id_test[misclassified_mask],
            'day_of_study': day_of_study_test[misclassified_mask],
            'true_label': split_data['y_test'][misclassified_mask],
            'predicted_label': preds[misclassified_mask]
        })
        # Save misclassified instances for this fold
        misclassified.to_csv(f"{OUTPUT_DIR}/{split_method}/fold_{fold}/misclassified.csv", index=False)

        if show_fold_results:
            # Print fold results
            print(f"\n\nFold {fold} results:")
            print(f"Accuracy: {accuracy:.4f}")
            print(f"F1-macro: {f1_macro:.4f}")
            print(f"F1-micro: {f1_micro:.4f}")
            print(f"F1-weighted: {f1_weighted:.4f}")
            print(f"Precision: {precision:.4f}")
            print(f"Recall: {recall:.4f}")
            print(f"ROC AUC: {roc_auc:.4f}")
            print(f"True Positives: {tp}, False Negatives: {fn}, False Positives: {fp}, True Negatives: {tn}")
            print(f"Classification report:\n{classification_report(split_data['y_test'], preds)}")
            # print(f"Classification report:\n{classification_report(split_data['y_train'], preds)}")

            print(f"Days of study for training set: {split_data['X_train']['day_of_study'].unique()}")
            print(f"Days of study for test set: {split_data['X_test']['day_of_study'].unique()}")
            print(f"Percentage of data used for training: {len(split_data['X_train']) / DS_LENGTH * 100:.2f}%")

            print(f"Misclassified instances in fold {fold}:")
            print(misclassified[['m_id', 'day_of_study', 'true_label', 'predicted_label']].head())

            print("-" * 50)
        
        if plot_feature_importances_per_fold:
            # Plot top k features for this fold
            top_indices = np.argsort(importances)[-TOP_FEATURES:][::-1]
            top_importances = importances[top_indices]

            plt.figure(figsize=(12, 4))
            plt.subplot(1, 2, 1)
            plt.barh(range(TOP_FEATURES), top_importances, color='skyblue', align='center')
            plt.yticks(range(TOP_FEATURES), feature_names[top_indices], ha="right")
            plt.ylabel("Feature Index")
            plt.xlabel("Importance")
            plt.title(f"Top {TOP_FEATURES} Feature Importances (Fold {fold})")
            # Plot confusion matrix
            plt.subplot(1, 2, 2)
            cm = confusion_matrix(split_data['y_test'], preds)
            sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
            plt.title(f'Confusion Matrix (Fold {fold})')
            plt.xlabel('Predicted Label')
            plt.ylabel('True Label')
            plt.tight_layout()
            plt.show()

        # Track results
        fold_accuracies.append(accuracy)
        fold_f1_macros.append(f1_macro)
        fold_f1_micros.append(f1_micro)
        fold_f1_weighted.append(f1_weighted)
        fold_precisions.append(precision)
        fold_recalls.append(recall)
        fold_roc_aucs.append(roc_auc)
        feature_importances.append(importances)
        true_positives.append(tp)
        false_negatives.append(fn)
        false_positives.append(fp)
        true_negatives.append(tn)

        # Save fold metrics to a CSV file
        fold_metrics = pd.DataFrame({
            'accuracy': [accuracy],
            'f1_macro': [f1_macro],
            'f1_micro': [f1_micro],
            'f1_weighted': [f1_weighted],
            'precision': [precision],
            'recall': [recall],
            'roc_auc': [roc_auc],
            'true_positives': [tp],
            'false_negatives': [fn],
            'false_positives': [fp],
            'true_negatives': [tn],
            'days_of_study_in_train': [split_data['X_train']['day_of_study'].unique()],
            'days_of_study_in_test': [split_data['X_test']['day_of_study'].unique()],
            'percentage_of_data_in_train': [len(split_data['X_train']) / DS_LENGTH * 100],
            'percentage_of_data_in_test': [len(split_data['X_test']) / DS_LENGTH * 100]
        })

        fold_metrics.to_csv(f"{OUTPUT_DIR}/{split_method}/fold_{fold}/metrics.csv", index=False)

        # Save top 15 feature importances to a csv file
        # top_indices = np.argsort(importances)[-TOP_FEATURES:][::-1]
        top_indices = np.argsort(importances)[::-1]
        top_importances = importances[top_indices]
        top_features = pd.DataFrame({
            'feature': feature_names[top_indices],
            'importance': top_importances
        })

        top_features.to_csv(f"{OUTPUT_DIR}/{split_method}/fold_{fold}/top_features.csv", index=False)

    print(f"\nAll Folds Completed.") 
    print("\n--------------------------------------------------")
    print("\nSummary of Results:\n")

    # Display best parameters summary
    if tune_hyperparameters:
        print("\nBest parameters per fold:")
        for fold, params in enumerate(best_params_per_fold):
            print(f"Fold {fold}: {params}")

    # Calculate mean importances across folds
    mean_importances = np.mean(feature_importances, axis=0)
    # Get indices of the top k features by mean
    top_indices_mean = np.argsort(mean_importances)[-TOP_FEATURES:][::-1]
    top_importances_mean = mean_importances[top_indices_mean]
    
    if plot_roc_and_feature_importances:

        # Plotting ROC curve side by side
        plt.figure(figsize=(15, 5))

        # ROC Curve Plot
        plt.subplot(1, 2, 1)  # First plot (1 row, 2 columns, 1st plot)
        if show_label:
            for i, (fpr, tpr) in enumerate(roc_curves):
                plt.plot(fpr, tpr, label=f'Fold {i} (ROC AUC = {fold_roc_aucs[i]:.2f})')
        else:
            for i, (fpr, tpr) in enumerate(roc_curves):
                plt.plot(fpr, tpr)
        plt.plot([0, 1], [0, 1], 'k--', label="Random Classifier")
        plt.title("ROC Curve Across Folds")
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.legend(loc="lower right")

        plt.subplot(1, 2, 2)  # Second plot (1 row, 2 columns, 2nd plot)
        plt.barh(range(TOP_FEATURES), top_importances_mean, color='skyblue', align='center')
        plt.yticks(range(TOP_FEATURES), feature_names[top_indices_mean])
        plt.ylabel("Feature Index")
        plt.xlabel("Importance")
        plt.title(f"Top {TOP_FEATURES} Feature Importances (Mean)")

        # Display the plots side by side
        plt.tight_layout()  # Adjust layout for better spacing
        plt.show()

    # Display summary statistics across folds
    print(f"\nSummary Across Folds:")
    print(f"Mean accuracy: {np.mean(fold_accuracies):.4f}")
    print(f"Mean F1-macro: {np.mean(fold_f1_macros):.4f}")
    print(f"Mean F1-micro: {np.mean(fold_f1_micros):.4f}")
    print(f"Mean F1-weighted: {np.mean(fold_f1_weighted):.4f}")
    print(f"Mean precision: {np.mean(fold_precisions):.4f}")
    print(f"Mean recall: {np.mean(fold_recalls):.4f}")
    print(f"Mean ROC AUC: {np.mean(fold_roc_aucs):.4f}")

    # Standard deviation, variance, coefficient of variation and dispersion index of f1_macro
    print(f"\nStandard Deviation of F1-macro: {np.std(fold_f1_macros):.4f}")
    print(f"Variance of F1-macro: {np.var(fold_f1_macros):.4f}")
    print(f"Coefficient of Variation of F1-macro: {np.std(fold_f1_macros) / np.mean(fold_f1_macros):.4f}")
    print(f"Dispersion Index of F1-macro: {np.var(fold_f1_macros) / np.mean(fold_f1_macros):.4f}")

    print("\n--------------------------------------------------")

    # Save summary statistics to a CSV file
    summary_metrics = pd.DataFrame({
        'accuracy': [np.mean(fold_accuracies)],
        'f1_macro': [np.mean(fold_f1_macros)],
        'f1_micro': [np.mean(fold_f1_micros)],
        'f1_weighted': [np.mean(fold_f1_weighted)],
        'precision': [np.mean(fold_precisions)],
        'recall': [np.mean(fold_recalls)],
        'roc_auc': [np.mean(fold_roc_aucs)],
        'std_f1_macro': [np.std(fold_f1_macros)],
        'var_f1_macro': [np.var(fold_f1_macros)],
        'cv_f1_macro': [np.std(fold_f1_macros) / np.mean(fold_f1_macros)],
        'di_f1_macro': [np.var(fold_f1_macros) / np.mean(fold_f1_macros)]
    })

    summary_metrics.to_csv(f"{OUTPUT_DIR}/{split_method}/summary_metrics.csv", index=False)

    # Save top feature importances and split method in a csv file
    top_features = pd.DataFrame({
        'feature': feature_names[top_indices_mean],
        'importance': top_importances_mean
    })

    top_features.to_csv(f"{OUTPUT_DIR}/{split_method}/top_features.csv", index=False) 

    # Optional: Calculate the most common parameters across folds
    if tune_hyperparameters:
        most_comon_params = max(set(best_params_per_fold), key=best_params_per_fold.count)
        print("\nMost common parameters across folds:")
        print(most_comon_params)

# %%
split_method, m_data = DataSplitting.grouped_combinations_split_with_sampling(df=df, seed=SEED, sample_size=50)

train_test_and_show_results(split_method=split_method, m_data=m_data, plot_feature_importances_per_fold=False, tune_hyperparameters=False, plot_roc_and_feature_importances=False, xgb_params=xgb_params)
# Out:
# Total possible combinations: 3060 of size 4
# Number of sampled combinations: 50
#
# Fold 0:
# Original train class distribution: Counter({0: 301, 1: 29})
# Original test class distribution: Counter({1: 37, 0: 15})
# Train IDs: [1258 1260 1261 1297 1299 1359 1361 1281 1285 1263 1264 1270 1380 1383]
# Test IDs: [1360 1276 1284 1382]
#
#
# Fold 0 results:
# Accuracy: 0.3462
# F1-macro: 0.3210
# F1-micro: 0.3462
# F1-weighted: 0.2658
# Precision: 0.8000
# Recall: 0.1081
# ROC AUC: 0.7586
# True Positives: 4, False Negatives: 33, False Positives: 1, True Negatives: 14
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.30      0.93      0.45        15
#            1       0.80      0.11      0.19        37
#
#     accuracy                           0.35        52
#    macro avg       0.55      0.52      0.32        52
# weighted avg       0.66      0.35      0.27        52
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 17 11 13 15 19 21 27 25 29 31  9 33
#  35 37 39 41 43 45 47 49]
# Days of study for test set: [11 14 16 18 20 22 15 17 19 23 25 27 29 31 33 35 37 39 41 45 10 13 21]
# Percentage of data used for training: 86.39%
# Misclassified instances in fold 0:
#     m_id  day_of_study  true_label  predicted_label
# 0   1360            11           0                1
# 15  1276            11           1                0
# 16  1276            15           1                0
# 17  1276            17           1                0
# 18  1276            17           1                0
# --------------------------------------------------
#
# Fold 1:
# Original train class distribution: Counter({0: 248, 1: 49})
# Original test class distribution: Counter({0: 68, 1: 17})
# Train IDs: [1261 1297 1299 1359 1360 1361 1276 1281 1284 1382 1263 1264 1380 1383]
# Test IDs: [1258 1260 1285 1270]
#
#
# Fold 1 results:
# Accuracy: 0.7882
# F1-macro: 0.4900
# F1-micro: 0.7882
# F1-weighted: 0.7240
# Precision: 0.3333
# Recall: 0.0588
# ROC AUC: 0.7318
# True Positives: 1, False Negatives: 16, False Positives: 2, True Negatives: 66
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.97      0.88        68
#            1       0.33      0.06      0.10        17
#
#     accuracy                           0.79        85
#    macro avg       0.57      0.51      0.49        85
# weighted avg       0.71      0.79      0.72        85
#
# Days of study for training set: [10 14 16 18 20 22 24 26 23 17 11 15 19 25 27 29 31 33 35 37 39 41 45 13
#  21 43 47 49]
# Days of study for test set: [14 18 20 22 24  7 10 12 16  8 15 17 19 21 23 25 27 29 31  9 33 35 37]
# Percentage of data used for training: 77.75%
# Misclassified instances in fold 1:
#     m_id  day_of_study  true_label  predicted_label
# 7   1258             7           0                1
# 25  1285            15           1                0
# 26  1285            15           1                0
# 27  1285            17           1                0
# 28  1285            17           1                0
# --------------------------------------------------
#
# Fold 2:
# Original train class distribution: Counter({0: 174, 1: 49})
# Original test class distribution: Counter({0: 142, 1: 17})
# Train IDs: [1258 1260 1261 1297 1299 1359 1360 1361 1276 1281 1284 1382 1270 1380]
# Test IDs: [1285 1263 1264 1383]
#
#
# Fold 2 results:
# Accuracy: 0.6101
# F1-macro: 0.4201
# F1-micro: 0.6101
# F1-weighted: 0.6810
# Precision: 0.0588
# Recall: 0.1765
# ROC AUC: 0.3558
# True Positives: 3, False Negatives: 14, False Positives: 48, True Negatives: 94
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.66      0.75       142
#            1       0.06      0.18      0.09        17
#
#     accuracy                           0.61       159
#    macro avg       0.46      0.42      0.42       159
# weighted avg       0.78      0.61      0.68       159
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 17 11 15 19 25 27 29 31 33 35 37 39
#  41 45 13 21]
# Days of study for test set: [15 17 19 21 23 25 27 29 31  9 11 14 33 35 37 39 41 43 45 47 49]
# Percentage of data used for training: 58.38%
# Misclassified instances in fold 2:
#    m_id  day_of_study  true_label  predicted_label
# 0  1285            15           1                0
# 1  1285            15           1                0
# 2  1285            17           1                0
# 3  1285            17           1                0
# 4  1285            19           1                0
# --------------------------------------------------
#
# Fold 3:
# Original train class distribution: Counter({0: 253, 1: 33})
# Original test class distribution: Counter({0: 63, 1: 33})
# Train IDs: [1258 1261 1297 1299 1359 1360 1361 1284 1285 1382 1263 1264 1270 1383]
# Test IDs: [1260 1276 1281 1380]
#
#
# Fold 3 results:
# Accuracy: 0.6875
# F1-macro: 0.5429
# F1-micro: 0.6875
# F1-weighted: 0.6232
# Precision: 0.6667
# Recall: 0.1818
# ROC AUC: 0.8283
# True Positives: 6, False Negatives: 27, False Positives: 3, True Negatives: 60
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.95      0.80        63
#            1       0.67      0.18      0.29        33
#
#     accuracy                           0.69        96
#    macro avg       0.68      0.57      0.54        96
# weighted avg       0.68      0.69      0.62        96
#
# Days of study for training set: [14 18 20 22 24  7 10 16 26 23 17 11 13 15 19 21 27 25 29 31  9 33 35 37
#  39 41 43 45 47 49]
# Days of study for test set: [10 12 14 16 18  8 11 15 17 19 23 25 27 29 31 33 35 37 39 41 45 13 21 20
#  22]
# Percentage of data used for training: 74.87%
# Misclassified instances in fold 3:
#     m_id  day_of_study  true_label  predicted_label
# 3   1260            12           0                1
# 16  1276            11           1                0
# 18  1276            17           1                0
# 21  1276            19           1                0
# 22  1276            23           1                0
# --------------------------------------------------
#
# Fold 4:
# Original train class distribution: Counter({0: 244, 1: 49})
# Original test class distribution: Counter({0: 72, 1: 17})
# Train IDs: [1258 1261 1297 1299 1360 1361 1276 1281 1284 1382 1263 1264 1270 1383]
# Test IDs: [1260 1359 1285 1380]
#
#
# Fold 4 results:
# Accuracy: 0.7865
# F1-macro: 0.4871
# F1-micro: 0.7865
# F1-weighted: 0.7293
# Precision: 0.2500
# Recall: 0.0588
# ROC AUC: 0.7059
# True Positives: 1, False Negatives: 16, False Positives: 3, True Negatives: 69
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.96      0.88        72
#            1       0.25      0.06      0.10        17
#
#     accuracy                           0.79        89
#    macro avg       0.53      0.51      0.49        89
# weighted avg       0.70      0.79      0.73        89
#
# Days of study for training set: [14 18 20 22 24  7 10 16 26 23 17 11 15 19 25 27 29 31 33 35 37 39 41 45
#  13 21 43 47 49]
# Days of study for test set: [10 12 14 16 18  8 11 15 17 19 21 23 25 27 29 31  9 20 22 33 35 37 39 41]
# Percentage of data used for training: 76.70%
# Misclassified instances in fold 4:
#     m_id  day_of_study  true_label  predicted_label
# 14  1260             8           0                1
# 16  1359            11           0                1
# 25  1285            15           1                0
# 26  1285            15           1                0
# 27  1285            17           1                0
# --------------------------------------------------
#
# Fold 5:
# Original train class distribution: Counter({0: 255, 1: 45})
# Original test class distribution: Counter({0: 61, 1: 21})
# Train IDs: [1258 1261 1297 1359 1360 1361 1281 1284 1285 1382 1263 1270 1380 1383]
# Test IDs: [1260 1299 1276 1264]
#
#
# Fold 5 results:
# Accuracy: 0.7317
# F1-macro: 0.5729
# F1-micro: 0.7317
# F1-weighted: 0.6999
# Precision: 0.4545
# Recall: 0.2381
# ROC AUC: 0.7127
# True Positives: 5, False Negatives: 16, False Positives: 6, True Negatives: 55
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        61
#            1       0.45      0.24      0.31        21
#
#     accuracy                           0.73        82
#    macro avg       0.61      0.57      0.57        82
# weighted avg       0.69      0.73      0.70        82
#
# Days of study for training set: [14 18 20 22 24  7 10 16 26 23 11 13 15 17 19 21 27 25 29 31  9 33 35 37
#  39 41 43 45 47 49]
# Days of study for test set: [10 12 14 16 18  8 17 11 15 19 23 25 27 29 31 33 35 37 39 41 45 21]
# Percentage of data used for training: 78.53%
# Misclassified instances in fold 5:
#     m_id  day_of_study  true_label  predicted_label
# 3   1260            12           0                1
# 14  1260             8           0                1
# 18  1276            11           1                0
# 19  1276            15           1                0
# 20  1276            17           1                0
# --------------------------------------------------
#
# Fold 6:
# Original train class distribution: Counter({0: 264, 1: 37})
# Original test class distribution: Counter({0: 52, 1: 29})
# Train IDs: [1260 1261 1297 1299 1359 1360 1361 1281 1285 1382 1263 1270 1380 1383]
# Test IDs: [1258 1276 1284 1264]
#
#
# Fold 6 results:
# Accuracy: 0.6914
# F1-macro: 0.6423
# F1-micro: 0.6914
# F1-weighted: 0.6799
# Precision: 0.5909
# Recall: 0.4483
# ROC AUC: 0.6870
# True Positives: 13, False Negatives: 16, False Positives: 9, True Negatives: 43
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.83      0.77        52
#            1       0.59      0.45      0.51        29
#
#     accuracy                           0.69        81
#    macro avg       0.66      0.64      0.64        81
# weighted avg       0.68      0.69      0.68        81
#
# Days of study for training set: [10 12 14 16 18  8 20 22 24 26 23 17 11 13 15 19 21 27 25 29 31  9 33 35
#  37 39 41 43 45 47 49]
# Days of study for test set: [14 18 20 22 24  7 11 15 17 19 23 25 27 29 31 33 35 37 39 41 45 10 13 21]
# Percentage of data used for training: 78.80%
# Misclassified instances in fold 6:
#     m_id  day_of_study  true_label  predicted_label
# 7   1258             7           0                1
# 8   1258             7           0                1
# 9   1276            11           1                0
# 12  1276            17           1                0
# 14  1276            19           1                0
# --------------------------------------------------
#
# Fold 7:
# Original train class distribution: Counter({0: 170, 1: 58})
# Original test class distribution: Counter({0: 146, 1: 8})
# Train IDs: [1258 1260 1261 1297 1299 1359 1360 1361 1276 1281 1285 1382 1270 1383]
# Test IDs: [1284 1263 1264 1380]
#
#
# Fold 7 results:
# Accuracy: 0.6753
# F1-macro: 0.4690
# F1-micro: 0.6753
# F1-weighted: 0.7656
# Precision: 0.0800
# Recall: 0.5000
# ROC AUC: 0.7543
# True Positives: 4, False Negatives: 4, False Positives: 46, True Negatives: 100
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.68      0.80       146
#            1       0.08      0.50      0.14         8
#
#     accuracy                           0.68       154
#    macro avg       0.52      0.59      0.47       154
# weighted avg       0.92      0.68      0.77       154
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 17 11 15 19 25 27 29 31 33 35 37 39
#  41 45 13 21  9 43 47 49]
# Days of study for test set: [10 13 15 17 19 21 23 27 11 14 25 29 31 33 35 37 39 41 43 45 47 18 20 22]
# Percentage of data used for training: 59.69%
# Misclassified instances in fold 7:
#    m_id  day_of_study  true_label  predicted_label
# 0  1284            10           1                0
# 1  1284            13           1                0
# 2  1284            15           1                0
# 3  1284            17           1                0
# 8  1263            11           0                1
# --------------------------------------------------
#
# Fold 8:
# Original train class distribution: Counter({0: 242, 1: 45})
# Original test class distribution: Counter({0: 74, 1: 21})
# Train IDs: [1260 1261 1297 1299 1360 1361 1281 1284 1285 1382 1264 1270 1380 1383]
# Test IDs: [1258 1359 1276 1263]
#
#
# Fold 8 results:
# Accuracy: 0.7158
# F1-macro: 0.5801
# F1-micro: 0.7158
# F1-weighted: 0.7133
# Precision: 0.3500
# Recall: 0.3333
# ROC AUC: 0.7227
# True Positives: 7, False Negatives: 14, False Positives: 13, True Negatives: 61
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.82        74
#            1       0.35      0.33      0.34        21
#
#     accuracy                           0.72        95
#    macro avg       0.58      0.58      0.58        95
# weighted avg       0.71      0.72      0.71        95
#
# Days of study for training set: [10 12 14 16 18  8 20 22 24 26 23 17 11 13 15 19 21 27 25 29 31  9 33 35
#  37 39 41 43 45 47 49]
# Days of study for test set: [14 18 20 22 24  7 11 16 15 17 19 23 25 27 29 31 33 35 37 39 41 45 21 43
#  47]
# Percentage of data used for training: 75.13%
# Misclassified instances in fold 8:
#     m_id  day_of_study  true_label  predicted_label
# 7   1258             7           0                1
# 8   1258             7           0                1
# 9   1359            11           0                1
# 18  1276            11           1                0
# 20  1276            17           1                0
# --------------------------------------------------
#
# Fold 9:
# Original train class distribution: Counter({0: 257, 1: 46})
# Original test class distribution: Counter({0: 59, 1: 20})
# Train IDs: [1258 1260 1261 1297 1299 1359 1360 1276 1285 1382 1263 1264 1270 1383]
# Test IDs: [1361 1281 1284 1380]
#
#
# Fold 9 results:
# Accuracy: 0.6962
# F1-macro: 0.4791
# F1-micro: 0.6962
# F1-weighted: 0.6451
# Precision: 0.2500
# Recall: 0.1000
# ROC AUC: 0.6288
# True Positives: 2, False Negatives: 18, False Positives: 6, True Negatives: 53
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.90      0.82        59
#            1       0.25      0.10      0.14        20
#
#     accuracy                           0.70        79
#    macro avg       0.50      0.50      0.48        79
# weighted avg       0.62      0.70      0.65        79
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 17 11 15 19 25 27 29 31 33 35 37 39
#  41 45 21  9 43 47 49]
# Days of study for test set: [11 14 16 18 20 10 13 15 17 19 21 23 27 22 25 29 31 33 35 37 39 41]
# Percentage of data used for training: 79.32%
# Misclassified instances in fold 9:
#     m_id  day_of_study  true_label  predicted_label
# 4   1361            16           0                1
# 12  1281            10           1                0
# 13  1281            13           1                0
# 14  1281            15           1                0
# 15  1281            17           1                0
# --------------------------------------------------
#
# Fold 10:
# Original train class distribution: Counter({0: 230, 1: 41})
# Original test class distribution: Counter({0: 86, 1: 25})
# Train IDs: [1258 1260 1261 1297 1299 1359 1360 1361 1276 1281 1284 1263 1264 1380]
# Test IDs: [1285 1382 1270 1383]
#
#
# Fold 10 results:
# Accuracy: 0.7658
# F1-macro: 0.5485
# F1-micro: 0.7658
# F1-weighted: 0.7206
# Precision: 0.4444
# Recall: 0.1600
# ROC AUC: 0.6595
# True Positives: 4, False Negatives: 21, False Positives: 5, True Negatives: 81
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.94      0.86        86
#            1       0.44      0.16      0.24        25
#
#     accuracy                           0.77       111
#    macro avg       0.62      0.55      0.55       111
# weighted avg       0.72      0.77      0.72       111
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 17 11 15 19 25 27 29 31 33 35 37 39
#  41 45 13 21 43 47]
# Days of study for test set: [15 17 19 21 23 25 27 29 31  9 11 10 33 35 37 39 41 43 45 47 49]
# Percentage of data used for training: 70.94%
# Misclassified instances in fold 10:
#    m_id  day_of_study  true_label  predicted_label
# 0  1285            15           1                0
# 1  1285            15           1                0
# 2  1285            17           1                0
# 3  1285            17           1                0
# 4  1285            19           1                0
# --------------------------------------------------
#
# Fold 11:
# Original train class distribution: Counter({0: 314, 1: 20})
# Original test class distribution: Counter({1: 46, 0: 2})
# Train IDs: [1258 1260 1261 1297 1359 1360 1361 1281 1382 1263 1264 1270 1380 1383]
# Test IDs: [1299 1276 1284 1285]
#
#
# Fold 11 results:
# Accuracy: 0.1667
# F1-macro: 0.1608
# F1-micro: 0.1667
# F1-weighted: 0.2249
# Precision: 1.0000
# Recall: 0.1304
# ROC AUC: 0.9457
# True Positives: 6, False Negatives: 40, False Positives: 0, True Negatives: 2
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.05      1.00      0.09         2
#            1       1.00      0.13      0.23        46
#
#     accuracy                           0.17        48
#    macro avg       0.52      0.57      0.16        48
# weighted avg       0.96      0.17      0.22        48
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 11 13 15 17 19 21 27 25 29 31 33 35
#  37 39 41 43 45 47 49]
# Days of study for test set: [17 11 15 19 23 25 27 29 31 33 35 37 39 41 45 10 13 21  9]
# Percentage of data used for training: 87.43%
# Misclassified instances in fold 11:
#    m_id  day_of_study  true_label  predicted_label
# 2  1276            11           1                0
# 3  1276            15           1                0
# 4  1276            17           1                0
# 5  1276            17           1                0
# 6  1276            19           1                0
# --------------------------------------------------
#
# Fold 12:
# Original train class distribution: Counter({0: 258, 1: 45})
# Original test class distribution: Counter({0: 58, 1: 21})
# Train IDs: [1260 1261 1297 1359 1360 1361 1281 1284 1285 1382 1263 1264 1270 1383]
# Test IDs: [1258 1299 1276 1380]
#
#
# Fold 12 results:
# Accuracy: 0.7595
# F1-macro: 0.6187
# F1-micro: 0.7595
# F1-weighted: 0.7272
# Precision: 0.6000
# Recall: 0.2857
# ROC AUC: 0.8128
# True Positives: 6, False Negatives: 15, False Positives: 4, True Negatives: 54
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.93      0.85        58
#            1       0.60      0.29      0.39        21
#
#     accuracy                           0.76        79
#    macro avg       0.69      0.61      0.62        79
# weighted avg       0.73      0.76      0.73        79
#
# Days of study for training set: [10 12 14 16 18  8 20 22 24 26 23 11 13 15 17 19 21 27 25 29 31  9 33 35
#  37 39 41 43 45 47 49]
# Days of study for test set: [14 18 20 22 24  7 17 11 15 19 23 25 27 29 31 33 35 37 39 41 45 21]
# Percentage of data used for training: 79.32%
# Misclassified instances in fold 12:
#     m_id  day_of_study  true_label  predicted_label
# 8   1258             7           0                1
# 11  1276            11           1                0
# 12  1276            15           1                0
# 14  1276            17           1                0
# 16  1276            19           1                0
# --------------------------------------------------
#
# Fold 13:
# Original train class distribution: Counter({0: 295, 1: 50})
# Original test class distribution: Counter({0: 21, 1: 16})
# Train IDs: [1258 1260 1261 1297 1299 1360 1276 1281 1285 1263 1264 1270 1380 1383]
# Test IDs: [1359 1361 1284 1382]
#
#
# Fold 13 results:
# Accuracy: 0.6757
# F1-macro: 0.6119
# F1-micro: 0.6757
# F1-weighted: 0.6332
# Precision: 0.8333
# Recall: 0.3125
# ROC AUC: 0.8214
# True Positives: 5, False Negatives: 11, False Positives: 1, True Negatives: 20
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.65      0.95      0.77        21
#            1       0.83      0.31      0.45        16
#
#     accuracy                           0.68        37
#    macro avg       0.74      0.63      0.61        37
# weighted avg       0.73      0.68      0.63        37
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 17 11 15 19 25 27 29 31 33 35 37 39
#  41 45 13 21  9 43 47 49]
# Days of study for test set: [11 14 16 18 20 10 13 15 17 19 21 23 27 25 29]
# Percentage of data used for training: 90.31%
# Misclassified instances in fold 13:
#     m_id  day_of_study  true_label  predicted_label
# 0   1359            11           0                1
# 21  1284            10           1                0
# 22  1284            13           1                0
# 23  1284            15           1                0
# 24  1284            17           1                0
# --------------------------------------------------
#
# Fold 14:
# Original train class distribution: Counter({0: 312, 1: 33})
# Original test class distribution: Counter({1: 33, 0: 4})
# Train IDs: [1258 1260 1261 1359 1360 1361 1284 1285 1382 1263 1264 1270 1380 1383]
# Test IDs: [1297 1299 1276 1281]
#
#
# Fold 14 results:
# Accuracy: 0.2432
# F1-macro: 0.2427
# F1-micro: 0.2432
# F1-weighted: 0.2587
# Precision: 1.0000
# Recall: 0.1515
# ROC AUC: 0.9773
# True Positives: 5, False Negatives: 28, False Positives: 0, True Negatives: 4
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.12      1.00      0.22         4
#            1       1.00      0.15      0.26        33
#
#     accuracy                           0.24        37
#    macro avg       0.56      0.58      0.24        37
# weighted avg       0.91      0.24      0.26        37
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 11 13 15 17 19 21 23 27 25 29 31  9 33
#  35 37 39 41 43 45 47 49]
# Days of study for test set: [23 17 11 15 19 25 27 29 31 33 35 37 39 41 45 10 13 21]
# Percentage of data used for training: 90.31%
# Misclassified instances in fold 14:
#    m_id  day_of_study  true_label  predicted_label
# 4  1276            11           1                0
# 5  1276            15           1                0
# 6  1276            17           1                0
# 7  1276            17           1                0
# 9  1276            19           1                0
# --------------------------------------------------
#
# Fold 15:
# Original train class distribution: Counter({0: 262, 1: 58})
# Original test class distribution: Counter({0: 54, 1: 8})
# Train IDs: [1260 1261 1297 1359 1360 1361 1276 1281 1284 1285 1263 1264 1270 1380]
# Test IDs: [1258 1299 1382 1383]
#
#
# Fold 15 results:
# Accuracy: 0.7742
# F1-macro: 0.4977
# F1-micro: 0.7742
# F1-weighted: 0.7742
# Precision: 0.1250
# Recall: 0.1250
# ROC AUC: 0.7176
# True Positives: 1, False Negatives: 7, False Positives: 7, True Negatives: 47
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87        54
#            1       0.12      0.12      0.12         8
#
#     accuracy                           0.77        62
#    macro avg       0.50      0.50      0.50        62
# weighted avg       0.77      0.77      0.77        62
#
# Days of study for training set: [10 12 14 16 18  8 20 22 24 26 23 11 15 17 19 25 27 29 31 33 35 37 39 41
#  45 13 21  9 43 47]
# Days of study for test set: [14 18 20 22 24  7 17 11 19 21 23 25 27 29 31 33 35 37 39 41 43 45 47 49]
# Percentage of data used for training: 83.77%
# Misclassified instances in fold 15:
#     m_id  day_of_study  true_label  predicted_label
# 11  1382            11           1                0
# 12  1382            17           1                0
# 14  1382            21           1                0
# 15  1382            23           1                0
# 16  1382            25           1                0
# --------------------------------------------------
#
# Fold 16:
# Original train class distribution: Counter({0: 264, 1: 28})
# Original test class distribution: Counter({0: 52, 1: 38})
# Train IDs: [1258 1260 1261 1297 1299 1360 1361 1281 1284 1382 1263 1264 1270 1380]
# Test IDs: [1359 1276 1285 1383]
#
#
# Fold 16 results:
# Accuracy: 0.5333
# F1-macro: 0.4034
# F1-micro: 0.5333
# F1-weighted: 0.4467
# Precision: 0.3000
# Recall: 0.0789
# ROC AUC: 0.5177
# True Positives: 3, False Negatives: 35, False Positives: 7, True Negatives: 45
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.87      0.68        52
#            1       0.30      0.08      0.12        38
#
#     accuracy                           0.53        90
#    macro avg       0.43      0.47      0.40        90
# weighted avg       0.45      0.53      0.45        90
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 17 11 13 15 19 21 27 25 29 31 33 35
#  37 39 41 43 45 47]
# Days of study for test set: [11 14 16 15 17 19 23 25 27 29 31 33 35 37 39 41 45 21  9 43 47 49]
# Percentage of data used for training: 76.44%
# Misclassified instances in fold 16:
#     m_id  day_of_study  true_label  predicted_label
# 0   1359            11           0                1
# 9   1276            11           1                0
# 10  1276            15           1                0
# 11  1276            17           1                0
# 12  1276            17           1                0
# --------------------------------------------------
#
# Fold 17:
# Original train class distribution: Counter({0: 244, 1: 58})
# Original test class distribution: Counter({0: 72, 1: 8})
# Train IDs: [1261 1297 1299 1359 1360 1361 1276 1281 1284 1285 1263 1264 1270 1383]
# Test IDs: [1258 1260 1382 1380]
#
#
# Fold 17 results:
# Accuracy: 0.8750
# F1-macro: 0.4667
# F1-micro: 0.8750
# F1-weighted: 0.8400
# Precision: 0.0000
# Recall: 0.0000
# ROC AUC: 0.8524
# True Positives: 0, False Negatives: 8, False Positives: 2, True Negatives: 70
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93        72
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.88        80
#    macro avg       0.45      0.49      0.47        80
# weighted avg       0.81      0.88      0.84        80
#
# Days of study for training set: [10 14 16 18 20 22 24 26 23 17 11 15 19 25 27 29 31 33 35 37 39 41 45 13
#  21  9 43 47 49]
# Days of study for test set: [14 18 20 22 24  7 10 12 16  8 11 17 19 21 23 25 27 29 31 33 35 37 39 41]
# Percentage of data used for training: 79.06%
# Misclassified instances in fold 17:
#     m_id  day_of_study  true_label  predicted_label
# 7   1258             7           0                1
# 25  1382            11           1                0
# 26  1382            17           1                0
# 27  1382            19           1                0
# 28  1382            21           1                0
# --------------------------------------------------
#
# Fold 18:
# Original train class distribution: Counter({0: 267, 1: 50})
# Original test class distribution: Counter({0: 49, 1: 16})
# Train IDs: [1258 1260 1261 1297 1359 1360 1361 1276 1281 1285 1263 1264 1270 1383]
# Test IDs: [1299 1284 1382 1380]
#
#
# Fold 18 results:
# Accuracy: 0.8000
# F1-macro: 0.6566
# F1-micro: 0.8000
# F1-weighted: 0.7693
# Precision: 0.7143
# Recall: 0.3125
# ROC AUC: 0.8712
# True Positives: 5, False Negatives: 11, False Positives: 2, True Negatives: 47
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.96      0.88        49
#            1       0.71      0.31      0.43        16
#
#     accuracy                           0.80        65
#    macro avg       0.76      0.64      0.66        65
# weighted avg       0.79      0.80      0.77        65
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 11 15 17 19 25 27 29 31 33 35 37 39
#  41 45 13 21  9 43 47 49]
# Days of study for test set: [17 10 13 15 19 21 23 27 11 25 29 18 20 22 31 33 35 37 39 41]
# Percentage of data used for training: 82.98%
# Misclassified instances in fold 18:
#     m_id  day_of_study  true_label  predicted_label
# 2   1284            10           1                0
# 3   1284            13           1                0
# 4   1284            15           1                0
# 5   1284            17           1                0
# 10  1382            11           1                0
# --------------------------------------------------
#
# Fold 19:
# Original train class distribution: Counter({0: 283, 1: 49})
# Original test class distribution: Counter({0: 33, 1: 17})
# Train IDs: [1258 1261 1299 1359 1361 1276 1281 1284 1382 1263 1264 1270 1380 1383]
# Test IDs: [1260 1297 1360 1285]
#
#
# Fold 19 results:
# Accuracy: 0.6800
# F1-macro: 0.4580
# F1-micro: 0.6800
# F1-weighted: 0.5690
# Precision: 1.0000
# Recall: 0.0588
# ROC AUC: 0.6631
# True Positives: 1, False Negatives: 16, False Positives: 0, True Negatives: 33
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80        33
#            1       1.00      0.06      0.11        17
#
#     accuracy                           0.68        50
#    macro avg       0.84      0.53      0.46        50
# weighted avg       0.78      0.68      0.57        50
#
# Days of study for training set: [14 18 20 22 24  7 10 16 26 17 11 15 19 23 25 27 29 31 33 35 37 39 41 45
#  13 21 43 47 49]
# Days of study for test set: [10 12 14 16 18  8 23 11 20 22 15 17 19 21 25 27 29 31  9]
# Percentage of data used for training: 86.91%
# Misclassified instances in fold 19:
#     m_id  day_of_study  true_label  predicted_label
# 33  1285            15           1                0
# 34  1285            15           1                0
# 35  1285            17           1                0
# 36  1285            17           1                0
# 37  1285            19           1                0
# --------------------------------------------------
#
# Fold 20:
# Original train class distribution: Counter({0: 183, 1: 45})
# Original test class distribution: Counter({0: 133, 1: 21})
# Train IDs: [1258 1260 1261 1297 1299 1359 1360 1361 1281 1284 1285 1382 1263 1270]
# Test IDs: [1276 1264 1380 1383]
#
#
# Fold 20 results:
# Accuracy: 0.7922
# F1-macro: 0.6180
# F1-micro: 0.7922
# F1-weighted: 0.8056
# Precision: 0.3103
# Recall: 0.4286
# ROC AUC: 0.7766
# True Positives: 9, False Negatives: 12, False Positives: 20, True Negatives: 113
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.85      0.88       133
#            1       0.31      0.43      0.36        21
#
#     accuracy                           0.79       154
#    macro avg       0.61      0.64      0.62       154
# weighted avg       0.82      0.79      0.81       154
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 17 11 13 15 19 21 27 25 29 31  9 33
#  35 37 39 41 43 45 47]
# Days of study for test set: [11 15 17 19 23 25 27 29 31 33 35 37 39 41 45 21 18 20 22 43 47 49]
# Percentage of data used for training: 59.69%
# Misclassified instances in fold 20:
#    m_id  day_of_study  true_label  predicted_label
# 0  1276            11           1                0
# 2  1276            17           1                0
# 5  1276            19           1                0
# 6  1276            23           1                0
# 8  1276            25           1                0
# --------------------------------------------------
#
# Fold 21:
# Original train class distribution: Counter({0: 258, 1: 46})
# Original test class distribution: Counter({0: 58, 1: 20})
# Train IDs: [1258 1260 1261 1297 1299 1359 1361 1276 1284 1285 1263 1264 1380 1383]
# Test IDs: [1360 1281 1382 1270]
#
#
# Fold 21 results:
# Accuracy: 0.7436
# F1-macro: 0.4708
# F1-micro: 0.7436
# F1-weighted: 0.6559
# Precision: 0.5000
# Recall: 0.0500
# ROC AUC: 0.9267
# True Positives: 1, False Negatives: 19, False Positives: 1, True Negatives: 57
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.98      0.85        58
#            1       0.50      0.05      0.09        20
#
#     accuracy                           0.74        78
#    macro avg       0.62      0.52      0.47        78
# weighted avg       0.69      0.74      0.66        78
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 17 11 15 19 25 27 29 31 33 35 37 39
#  41 45 13 21  9 43 47 49]
# Days of study for test set: [11 14 16 18 20 22 10 13 15 17 19 21 23 27 25 29 31 33 35 37]
# Percentage of data used for training: 79.58%
# Misclassified instances in fold 21:
#     m_id  day_of_study  true_label  predicted_label
# 15  1281            10           1                0
# 16  1281            13           1                0
# 17  1281            15           1                0
# 18  1281            17           1                0
# 19  1281            17           1                0
# --------------------------------------------------
#
# Fold 22:
# Original train class distribution: Counter({0: 230, 1: 33})
# Original test class distribution: Counter({0: 86, 1: 33})
# Train IDs: [1258 1260 1261 1297 1299 1359 1360 1361 1284 1285 1382 1263 1380 1383]
# Test IDs: [1276 1281 1264 1270]
#
#
# Fold 22 results:
# Accuracy: 0.7227
# F1-macro: 0.5625
# F1-micro: 0.7227
# F1-weighted: 0.6804
# Precision: 0.5000
# Recall: 0.2121
# ROC AUC: 0.8136
# True Positives: 7, False Negatives: 26, False Positives: 7, True Negatives: 79
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.92      0.83        86
#            1       0.50      0.21      0.30        33
#
#     accuracy                           0.72       119
#    macro avg       0.63      0.57      0.56       119
# weighted avg       0.68      0.72      0.68       119
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 17 11 13 15 19 21 27 25 29 31  9 33
#  35 37 39 41 43 45 47 49]
# Days of study for test set: [11 15 17 19 23 25 27 29 31 33 35 37 39 41 45 10 13 21]
# Percentage of data used for training: 68.85%
# Misclassified instances in fold 22:
#    m_id  day_of_study  true_label  predicted_label
# 0  1276            11           1                0
# 3  1276            17           1                0
# 5  1276            19           1                0
# 6  1276            23           1                0
# 7  1276            23           1                0
# --------------------------------------------------
#
# Fold 23:
# Original train class distribution: Counter({0: 271, 1: 33})
# Original test class distribution: Counter({0: 45, 1: 33})
# Train IDs: [1258 1260 1261 1297 1359 1360 1361 1284 1285 1382 1263 1264 1270 1380]
# Test IDs: [1299 1276 1281 1383]
#
#
# Fold 23 results:
# Accuracy: 0.5769
# F1-macro: 0.5091
# F1-micro: 0.5769
# F1-weighted: 0.5371
# Precision: 0.5000
# Recall: 0.2424
# ROC AUC: 0.6667
# True Positives: 8, False Negatives: 25, False Positives: 8, True Negatives: 37
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.82      0.69        45
#            1       0.50      0.24      0.33        33
#
#     accuracy                           0.58        78
#    macro avg       0.55      0.53      0.51        78
# weighted avg       0.56      0.58      0.54        78
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 11 13 15 17 19 21 27 25 29 31  9 33
#  35 37 39 41 43 45 47]
# Days of study for test set: [17 11 15 19 23 25 27 29 31 33 35 37 39 41 45 10 13 21 43 47 49]
# Percentage of data used for training: 79.58%
# Misclassified instances in fold 23:
#     m_id  day_of_study  true_label  predicted_label
# 2   1276            11           1                0
# 4   1276            17           1                0
# 7   1276            19           1                0
# 10  1276            25           1                0
# 12  1276            27           1                0
# --------------------------------------------------
#
# Fold 24:
# Original train class distribution: Counter({0: 300, 1: 45})
# Original test class distribution: Counter({1: 21, 0: 16})
# Train IDs: [1258 1260 1261 1359 1360 1281 1284 1285 1382 1263 1264 1270 1380 1383]
# Test IDs: [1297 1299 1361 1276]
#
#
# Fold 24 results:
# Accuracy: 0.4865
# F1-macro: 0.4261
# F1-micro: 0.4865
# F1-weighted: 0.4010
# Precision: 0.7500
# Recall: 0.1429
# ROC AUC: 0.7619
# True Positives: 3, False Negatives: 18, False Positives: 1, True Negatives: 15
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.45      0.94      0.61        16
#            1       0.75      0.14      0.24        21
#
#     accuracy                           0.49        37
#    macro avg       0.60      0.54      0.43        37
# weighted avg       0.62      0.49      0.40        37
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 11 13 15 17 19 21 23 27 25 29 31  9 33
#  35 37 39 41 43 45 47 49]
# Days of study for test set: [23 17 11 14 16 18 20 15 19 25 27 29 31 33 35 37 39 41 45]
# Percentage of data used for training: 90.31%
# Misclassified instances in fold 24:
#     m_id  day_of_study  true_label  predicted_label
# 8   1361            16           0                1
# 16  1276            11           1                0
# 17  1276            15           1                0
# 18  1276            17           1                0
# 19  1276            17           1                0
# --------------------------------------------------
#
# Fold 25:
# Original train class distribution: Counter({0: 286, 1: 49})
# Original test class distribution: Counter({0: 30, 1: 17})
# Train IDs: [1258 1261 1297 1359 1360 1276 1281 1284 1382 1263 1264 1270 1380 1383]
# Test IDs: [1260 1299 1361 1285]
#
#
# Fold 25 results:
# Accuracy: 0.6170
# F1-macro: 0.4284
# F1-micro: 0.6170
# F1-weighted: 0.5192
# Precision: 0.3333
# Recall: 0.0588
# ROC AUC: 0.6157
# True Positives: 1, False Negatives: 16, False Positives: 2, True Negatives: 28
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.64      0.93      0.76        30
#            1       0.33      0.06      0.10        17
#
#     accuracy                           0.62        47
#    macro avg       0.48      0.50      0.43        47
# weighted avg       0.53      0.62      0.52        47
#
# Days of study for training set: [14 18 20 22 24  7 10 16 26 23 11 15 17 19 25 27 29 31 33 35 37 39 41 45
#  13 21 43 47 49]
# Days of study for test set: [10 12 14 16 18  8 17 11 20 15 19 21 23 25 27 29 31  9]
# Percentage of data used for training: 87.70%
# Misclassified instances in fold 25:
#     m_id  day_of_study  true_label  predicted_label
# 14  1260             8           0                1
# 20  1361            16           0                1
# 30  1285            15           1                0
# 31  1285            15           1                0
# 32  1285            17           1                0
# --------------------------------------------------
#
# Fold 26:
# Original train class distribution: Counter({0: 287, 1: 45})
# Original test class distribution: Counter({0: 29, 1: 21})
# Train IDs: [1258 1260 1261 1299 1359 1281 1284 1285 1382 1263 1264 1270 1380 1383]
# Test IDs: [1297 1360 1361 1276]
#
#
# Fold 26 results:
# Accuracy: 0.6200
# F1-macro: 0.5386
# F1-micro: 0.6200
# F1-weighted: 0.5696
# Precision: 0.6250
# Recall: 0.2381
# ROC AUC: 0.7800
# True Positives: 5, False Negatives: 16, False Positives: 3, True Negatives: 26
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.62      0.90      0.73        29
#            1       0.62      0.24      0.34        21
#
#     accuracy                           0.62        50
#    macro avg       0.62      0.57      0.54        50
# weighted avg       0.62      0.62      0.57        50
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 17 11 13 15 19 21 23 27 25 29 31  9 33
#  35 37 39 41 43 45 47 49]
# Days of study for test set: [23 11 14 16 18 20 22 15 17 19 25 27 29 31 33 35 37 39 41 45]
# Percentage of data used for training: 86.91%
# Misclassified instances in fold 26:
#     m_id  day_of_study  true_label  predicted_label
# 2   1360            11           0                1
# 4   1360            16           0                1
# 19  1361            16           0                1
# 29  1276            11           1                0
# 30  1276            15           1                0
# --------------------------------------------------
#
# Fold 27:
# Original train class distribution: Counter({0: 252, 1: 54})
# Original test class distribution: Counter({0: 64, 1: 12})
# Train IDs: [1258 1260 1261 1297 1299 1360 1276 1284 1285 1382 1263 1270 1380 1383]
# Test IDs: [1359 1361 1281 1264]
#
#
# Fold 27 results:
# Accuracy: 0.7895
# F1-macro: 0.6498
# F1-micro: 0.7895
# F1-weighted: 0.8011
# Precision: 0.3750
# Recall: 0.5000
# ROC AUC: 0.7956
# True Positives: 6, False Negatives: 6, False Positives: 10, True Negatives: 54
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87        64
#            1       0.38      0.50      0.43        12
#
#     accuracy                           0.79        76
#    macro avg       0.64      0.67      0.65        76
# weighted avg       0.82      0.79      0.80        76
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 17 11 15 19 25 27 29 31 33 35 37 39
#  41 45 13 21  9 43 47 49]
# Days of study for test set: [11 14 16 18 20 10 13 15 17 19 21 23 27 25 29 31 33 35 37 39]
# Percentage of data used for training: 80.10%
# Misclassified instances in fold 27:
#     m_id  day_of_study  true_label  predicted_label
# 21  1281            10           1                0
# 22  1281            13           1                0
# 23  1281            15           1                0
# 24  1281            17           1                0
# 26  1281            19           1                0
# --------------------------------------------------
#
# Fold 28:
# Original train class distribution: Counter({0: 253, 1: 28})
# Original test class distribution: Counter({0: 63, 1: 38})
# Train IDs: [1258 1261 1297 1299 1359 1360 1361 1281 1284 1382 1263 1264 1270 1383]
# Test IDs: [1260 1276 1285 1380]
#
#
# Fold 28 results:
# Accuracy: 0.6436
# F1-macro: 0.4389
# F1-micro: 0.6436
# F1-weighted: 0.5228
# Precision: 1.0000
# Recall: 0.0526
# ROC AUC: 0.7414
# True Positives: 2, False Negatives: 36, False Positives: 0, True Negatives: 63
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.64      1.00      0.78        63
#            1       1.00      0.05      0.10        38
#
#     accuracy                           0.64       101
#    macro avg       0.82      0.53      0.44       101
# weighted avg       0.77      0.64      0.52       101
#
# Days of study for training set: [14 18 20 22 24  7 10 16 26 23 17 11 13 15 19 21 27 25 29 31 33 35 37 39
#  41 43 45 47 49]
# Days of study for test set: [10 12 14 16 18  8 11 15 17 19 23 25 27 29 31 33 35 37 39 41 45 21  9 20
#  22]
# Percentage of data used for training: 73.56%
# Misclassified instances in fold 28:
#     m_id  day_of_study  true_label  predicted_label
# 16  1276            11           1                0
# 17  1276            15           1                0
# 18  1276            17           1                0
# 19  1276            17           1                0
# 20  1276            19           1                0
# --------------------------------------------------
#
# Fold 29:
# Original train class distribution: Counter({0: 208, 1: 49})
# Original test class distribution: Counter({0: 108, 1: 17})
# Train IDs: [1260 1261 1297 1299 1359 1360 1361 1276 1281 1284 1382 1264 1270 1380]
# Test IDs: [1258 1285 1263 1383]
#
#
# Fold 29 results:
# Accuracy: 0.6800
# F1-macro: 0.4484
# F1-micro: 0.6800
# F1-weighted: 0.7086
# Precision: 0.0741
# Recall: 0.1176
# ROC AUC: 0.4379
# True Positives: 2, False Negatives: 15, False Positives: 25, True Negatives: 83
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.77      0.81       108
#            1       0.07      0.12      0.09        17
#
#     accuracy                           0.68       125
#    macro avg       0.46      0.44      0.45       125
# weighted avg       0.74      0.68      0.71       125
#
# Days of study for training set: [10 12 14 16 18  8 20 22 24 26 23 17 11 15 19 25 27 29 31 33 35 37 39 41
#  45 13 21]
# Days of study for test set: [14 18 20 22 24  7 15 17 19 21 23 25 27 29 31  9 11 33 35 37 39 41 43 45
#  47 49]
# Percentage of data used for training: 67.28%
# Misclassified instances in fold 29:
#     m_id  day_of_study  true_label  predicted_label
# 0   1258            14           0                1
# 7   1258             7           0                1
# 9   1285            15           1                0
# 10  1285            15           1                0
# 11  1285            17           1                0
# --------------------------------------------------
#
# Fold 30:
# Original train class distribution: Counter({0: 273, 1: 16})
# Original test class distribution: Counter({1: 50, 0: 43})
# Train IDs: [1258 1260 1261 1297 1299 1359 1360 1361 1284 1382 1263 1270 1380 1383]
# Test IDs: [1276 1281 1285 1264]
#
#
# Fold 30 results:
# Accuracy: 0.4946
# F1-macro: 0.3933
# F1-micro: 0.4946
# F1-weighted: 0.3747
# Precision: 0.8000
# Recall: 0.0800
# ROC AUC: 0.5614
# True Positives: 4, False Negatives: 46, False Positives: 1, True Negatives: 42
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.48      0.98      0.64        43
#            1       0.80      0.08      0.15        50
#
#     accuracy                           0.49        93
#    macro avg       0.64      0.53      0.39        93
# weighted avg       0.65      0.49      0.37        93
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 17 11 13 15 19 21 27 25 29 31 33 35
#  37 39 41 43 45 47 49]
# Days of study for test set: [11 15 17 19 23 25 27 29 31 33 35 37 39 41 45 10 13 21  9]
# Percentage of data used for training: 75.65%
# Misclassified instances in fold 30:
#    m_id  day_of_study  true_label  predicted_label
# 0  1276            11           1                0
# 1  1276            15           1                0
# 2  1276            17           1                0
# 3  1276            17           1                0
# 4  1276            19           1                0
# --------------------------------------------------
#
# Fold 31:
# Original train class distribution: Counter({0: 312, 1: 37})
# Original test class distribution: Counter({1: 29, 0: 4})
# Train IDs: [1258 1260 1261 1359 1360 1361 1281 1284 1285 1263 1264 1270 1380 1383]
# Test IDs: [1297 1299 1276 1382]
#
#
# Fold 31 results:
# Accuracy: 0.3333
# F1-macro: 0.3278
# F1-micro: 0.3333
# F1-weighted: 0.3741
# Precision: 1.0000
# Recall: 0.2414
# ROC AUC: 0.8103
# True Positives: 7, False Negatives: 22, False Positives: 0, True Negatives: 4
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.15      1.00      0.27         4
#            1       1.00      0.24      0.39        29
#
#     accuracy                           0.33        33
#    macro avg       0.58      0.62      0.33        33
# weighted avg       0.90      0.33      0.37        33
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 11 13 15 17 19 21 23 27 25 29 31  9 33
#  35 37 39 41 43 45 47 49]
# Days of study for test set: [23 17 11 15 19 25 27 29 31 33 35 37 39 41 45 21]
# Percentage of data used for training: 91.36%
# Misclassified instances in fold 31:
#    m_id  day_of_study  true_label  predicted_label
# 4  1276            11           1                0
# 5  1276            15           1                0
# 6  1276            17           1                0
# 7  1276            17           1                0
# 9  1276            19           1                0
# --------------------------------------------------
#
# Fold 32:
# Original train class distribution: Counter({0: 252, 1: 49})
# Original test class distribution: Counter({0: 64, 1: 17})
# Train IDs: [1258 1260 1297 1359 1360 1361 1276 1281 1284 1382 1263 1264 1270 1380]
# Test IDs: [1261 1299 1285 1383]
#
#
# Fold 32 results:
# Accuracy: 0.7160
# F1-macro: 0.4889
# F1-micro: 0.7160
# F1-weighted: 0.6866
# Precision: 0.2000
# Recall: 0.1176
# ROC AUC: 0.5386
# True Positives: 2, False Negatives: 15, False Positives: 8, True Negatives: 56
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83        64
#            1       0.20      0.12      0.15        17
#
#     accuracy                           0.72        81
#    macro avg       0.49      0.50      0.49        81
# ...
#    macro avg       0.48      0.48      0.48        91
# weighted avg       0.69      0.71      0.70        91
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 23 17 11 15 19 25 27 29 31 33 35 37 39 41
#  45 13 21 43 47 49]
# Days of study for test set: [10 14 16 18 20 22 24 26 11 15 17 19 21 23 25 27 29 31  9 33 35 37 39]
# Percentage of data used for training: 76.18%
# Misclassified instances in fold 39:
#     m_id  day_of_study  true_label  predicted_label
# 0   1261            10           0                1
# 19  1361            11           0                1
# 21  1361            16           0                1
# 31  1285            15           1                0
# 32  1285            15           1                0
# --------------------------------------------------
#
# Fold 40:
# Original train class distribution: Counter({0: 283, 1: 54})
# Original test class distribution: Counter({0: 33, 1: 12})
# Train IDs: [1260 1261 1297 1299 1361 1276 1284 1285 1382 1263 1264 1270 1380 1383]
# Test IDs: [1258 1359 1360 1281]
#
#
# Fold 40 results:
# Accuracy: 0.8222
# F1-macro: 0.6959
# F1-micro: 0.8222
# F1-weighted: 0.7874
# Precision: 1.0000
# Recall: 0.3333
# ROC AUC: 0.9167
# True Positives: 4, False Negatives: 8, False Positives: 0, True Negatives: 33
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89        33
#            1       1.00      0.33      0.50        12
#
#     accuracy                           0.82        45
#    macro avg       0.90      0.67      0.70        45
# weighted avg       0.86      0.82      0.79        45
#
# Days of study for training set: [10 12 14 16 18  8 20 22 24 26 23 17 11 15 19 25 27 29 31 33 35 37 39 41
#  45 13 21  9 43 47 49]
# Days of study for test set: [14 18 20 22 24  7 11 16 10 13 15 17 19 21 23 27]
# Percentage of data used for training: 88.22%
# Misclassified instances in fold 40:
#     m_id  day_of_study  true_label  predicted_label
# 33  1281            10           1                0
# 34  1281            13           1                0
# 35  1281            15           1                0
# 36  1281            17           1                0
# 37  1281            17           1                0
# --------------------------------------------------
#
# Fold 41:
# Original train class distribution: Counter({0: 208, 1: 45})
# Original test class distribution: Counter({0: 108, 1: 21})
# Train IDs: [1258 1260 1261 1297 1299 1360 1361 1281 1284 1285 1382 1264 1380 1383]
# Test IDs: [1359 1276 1263 1270]
#
#
# Fold 41 results:
# Accuracy: 0.8140
# F1-macro: 0.6297
# F1-micro: 0.8140
# F1-weighted: 0.8059
# Precision: 0.4118
# Recall: 0.3333
# ROC AUC: 0.7981
# True Positives: 7, False Negatives: 14, False Positives: 10, True Negatives: 98
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89       108
#            1       0.41      0.33      0.37        21
#
#     accuracy                           0.81       129
#    macro avg       0.64      0.62      0.63       129
# weighted avg       0.80      0.81      0.81       129
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 17 11 13 15 19 21 27 25 29 31  9 33
#  35 37 39 41 43 45 47 49]
# Days of study for test set: [11 14 16 15 17 19 23 25 27 29 31 33 35 37 39 41 45 21 43 47 10]
# Percentage of data used for training: 66.23%
# Misclassified instances in fold 41:
#     m_id  day_of_study  true_label  predicted_label
# 9   1276            11           1                0
# 10  1276            15           1                0
# 11  1276            17           1                0
# 12  1276            17           1                0
# 14  1276            19           1                0
# --------------------------------------------------
#
# Fold 42:
# Original train class distribution: Counter({0: 245, 1: 45})
# Original test class distribution: Counter({0: 71, 1: 21})
# Train IDs: [1258 1261 1297 1299 1359 1360 1281 1284 1285 1382 1263 1264 1270 1380]
# Test IDs: [1260 1361 1276 1383]
#
#
# Fold 42 results:
# Accuracy: 0.7174
# F1-macro: 0.5847
# F1-micro: 0.7174
# F1-weighted: 0.7123
# Precision: 0.3684
# Recall: 0.3333
# ROC AUC: 0.6667
# True Positives: 7, False Negatives: 14, False Positives: 12, True Negatives: 59
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82        71
#            1       0.37      0.33      0.35        21
#
#     accuracy                           0.72        92
#    macro avg       0.59      0.58      0.58        92
# weighted avg       0.71      0.72      0.71        92
#
# Days of study for training set: [14 18 20 22 24  7 10 16 26 23 17 11 13 15 19 21 27 25 29 31  9 33 35 37
#  39 41 43 45 47]
# Days of study for test set: [10 12 14 16 18  8 11 20 15 17 19 23 25 27 29 31 33 35 37 39 41 45 21 43
#  47 49]
# Percentage of data used for training: 75.92%
# Misclassified instances in fold 42:
#     m_id  day_of_study  true_label  predicted_label
# 3   1260            12           0                1
# 14  1260             8           0                1
# 18  1361            16           0                1
# 28  1276            11           1                0
# 29  1276            15           1                0
# --------------------------------------------------
#
# Fold 43:
# Original train class distribution: Counter({0: 183, 1: 54})
# Original test class distribution: Counter({0: 133, 1: 12})
# Train IDs: [1258 1260 1261 1297 1299 1359 1360 1361 1276 1284 1285 1382 1263 1270]
# Test IDs: [1281 1264 1380 1383]
#
#
# Fold 43 results:
# Accuracy: 0.7655
# F1-macro: 0.5445
# F1-micro: 0.7655
# F1-weighted: 0.8093
# Precision: 0.1562
# Recall: 0.4167
# ROC AUC: 0.8264
# True Positives: 5, False Negatives: 7, False Positives: 27, True Negatives: 106
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86       133
#            1       0.16      0.42      0.23        12
#
#     accuracy                           0.77       145
#    macro avg       0.55      0.61      0.54       145
# weighted avg       0.87      0.77      0.81       145
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 17 11 15 19 25 27 29 31 33 35 37 39
#  41 45 13 21  9 43 47]
# Days of study for test set: [10 13 15 17 19 21 23 27 11 25 29 31 33 35 37 39 18 20 22 41 43 45 47 49]
# Percentage of data used for training: 62.04%
# Misclassified instances in fold 43:
#    m_id  day_of_study  true_label  predicted_label
# 0  1281            10           1                0
# 1  1281            13           1                0
# 2  1281            15           1                0
# 3  1281            17           1                0
# 4  1281            17           1                0
# --------------------------------------------------
#
# Fold 44:
# Original train class distribution: Counter({0: 256, 1: 58})
# Original test class distribution: Counter({0: 60, 1: 8})
# Train IDs: [1258 1260 1261 1299 1359 1361 1276 1281 1284 1285 1263 1264 1380 1383]
# Test IDs: [1297 1360 1382 1270]
#
#
# Fold 44 results:
# Accuracy: 0.8529
# F1-macro: 0.4603
# F1-micro: 0.8529
# F1-weighted: 0.8123
# Precision: 0.0000
# Recall: 0.0000
# ROC AUC: 0.8813
# True Positives: 0, False Negatives: 8, False Positives: 2, True Negatives: 58
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92        60
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.85        68
#    macro avg       0.44      0.48      0.46        68
# weighted avg       0.78      0.85      0.81        68
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 17 11 15 19 23 25 27 29 31 33 35 37 39
#  41 45 13 21  9 43 47 49]
# Days of study for test set: [23 11 14 16 18 20 22 17 19 21 25 27 29 10 15 31 33 35 37]
# Percentage of data used for training: 82.20%
# Misclassified instances in fold 44:
#     m_id  day_of_study  true_label  predicted_label
# 17  1382            11           1                0
# 18  1382            17           1                0
# 19  1382            19           1                0
# 20  1382            21           1                0
# 21  1382            23           1                0
# --------------------------------------------------
#
# Fold 45:
# Original train class distribution: Counter({0: 259, 1: 54})
# Original test class distribution: Counter({0: 57, 1: 12})
# Train IDs: [1258 1260 1261 1297 1359 1360 1276 1284 1285 1382 1263 1264 1270 1380]
# Test IDs: [1299 1361 1281 1383]
#
#
# Fold 45 results:
# Accuracy: 0.7536
# F1-macro: 0.6464
# F1-micro: 0.7536
# F1-weighted: 0.7734
# Precision: 0.3684
# Recall: 0.5833
# ROC AUC: 0.8041
# True Positives: 7, False Negatives: 5, False Positives: 12, True Negatives: 45
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.79      0.84        57
#            1       0.37      0.58      0.45        12
#
#     accuracy                           0.75        69
#    macro avg       0.63      0.69      0.65        69
# weighted avg       0.81      0.75      0.77        69
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 11 15 17 19 25 27 29 31 33 35 37 39
#  41 45 13 21  9 43 47]
# Days of study for test set: [17 11 14 16 18 20 10 13 15 19 21 23 27 25 29 31 33 35 37 39 41 43 45 47
#  49]
# Percentage of data used for training: 81.94%
# Misclassified instances in fold 45:
#     m_id  day_of_study  true_label  predicted_label
# 6   1361            16           0                1
# 14  1281            10           1                0
# 16  1281            15           1                0
# 19  1281            19           1                0
# 20  1281            19           1                0
# --------------------------------------------------
#
# Fold 46:
# Original train class distribution: Counter({0: 242, 1: 58})
# Original test class distribution: Counter({0: 74, 1: 8})
# Train IDs: [1258 1260 1297 1299 1359 1360 1276 1281 1285 1382 1263 1270 1380 1383]
# Test IDs: [1261 1361 1284 1264]
#
#
# Fold 46 results:
# Accuracy: 0.8049
# F1-macro: 0.6095
# F1-micro: 0.8049
# F1-weighted: 0.8318
# Precision: 0.2500
# Recall: 0.5000
# ROC AUC: 0.7753
# True Positives: 4, False Negatives: 4, False Positives: 12, True Negatives: 62
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.84      0.89        74
#            1       0.25      0.50      0.33         8
#
#     accuracy                           0.80        82
#    macro avg       0.59      0.67      0.61        82
# weighted avg       0.87      0.80      0.83        82
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 23 17 11 15 19 25 27 29 31 33 35 37 39 41
#  45 13 21  9 43 47 49]
# Days of study for test set: [10 14 16 18 20 22 24 26 11 13 15 17 19 21 23 27 25 29 31 33 35 37 39]
# Percentage of data used for training: 78.53%
# Misclassified instances in fold 46:
#     m_id  day_of_study  true_label  predicted_label
# 0   1261            10           0                1
# 5   1261            18           0                1
# 21  1361            16           0                1
# 23  1361            16           0                1
# 31  1284            10           1                0
# --------------------------------------------------
#
# Fold 47:
# Original train class distribution: Counter({0: 296, 1: 58})
# Original test class distribution: Counter({0: 20, 1: 8})
# Train IDs: [1260 1261 1297 1360 1361 1276 1281 1284 1285 1263 1264 1270 1380 1383]
# Test IDs: [1258 1299 1359 1382]
#
#
# Fold 47 results:
# Accuracy: 0.6429
# F1-macro: 0.3913
# F1-micro: 0.6429
# F1-weighted: 0.5590
# Precision: 0.0000
# Recall: 0.0000
# ROC AUC: 0.7312
# True Positives: 0, False Negatives: 8, False Positives: 2, True Negatives: 18
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.90      0.78        20
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.64        28
#    macro avg       0.35      0.45      0.39        28
# weighted avg       0.49      0.64      0.56        28
#
# Days of study for training set: [10 12 14 16 18  8 20 22 24 26 23 11 15 17 19 25 27 29 31 33 35 37 39 41
#  45 13 21  9 43 47 49]
# Days of study for test set: [14 18 20 22 24  7 17 11 16 19 21 23 25 27 29]
# Percentage of data used for training: 92.67%
# Misclassified instances in fold 47:
#     m_id  day_of_study  true_label  predicted_label
# 0   1258            14           0                1
# 11  1359            11           0                1
# 20  1382            11           1                0
# 21  1382            17           1                0
# 22  1382            19           1                0
# --------------------------------------------------
#
# Fold 48:
# Original train class distribution: Counter({0: 314, 1: 29})
# Original test class distribution: Counter({1: 37, 0: 2})
# Train IDs: [1258 1260 1261 1297 1359 1360 1361 1276 1382 1263 1264 1270 1380 1383]
# Test IDs: [1299 1281 1284 1285]
#
#
# Fold 48 results:
# Accuracy: 0.1282
# F1-macro: 0.1276
# F1-micro: 0.1282
# F1-weighted: 0.1477
# Precision: 1.0000
# Recall: 0.0811
# ROC AUC: 0.9730
# True Positives: 3, False Negatives: 34, False Positives: 0, True Negatives: 2
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.06      1.00      0.11         2
#            1       1.00      0.08      0.15        37
#
#     accuracy                           0.13        39
#    macro avg       0.53      0.54      0.13        39
# weighted avg       0.95      0.13      0.15        39
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 11 15 17 19 25 27 29 31 33 35 37 39
#  41 45 21 43 47 49]
# Days of study for test set: [17 10 13 15 19 21 23 27 25 29 31  9]
# Percentage of data used for training: 89.79%
# Misclassified instances in fold 48:
#    m_id  day_of_study  true_label  predicted_label
# 2  1281            10           1                0
# 3  1281            13           1                0
# 4  1281            15           1                0
# 5  1281            17           1                0
# 6  1281            17           1                0
# --------------------------------------------------
#
# Fold 49:
# Original train class distribution: Counter({0: 210, 1: 58})
# Original test class distribution: Counter({0: 106, 1: 8})
# Train IDs: [1258 1261 1297 1299 1359 1360 1361 1276 1281 1285 1382 1263 1270 1383]
# Test IDs: [1260 1284 1264 1380]
#
#
# Fold 49 results:
# Accuracy: 0.8421
# F1-macro: 0.6093
# F1-micro: 0.8421
# F1-weighted: 0.8686
# Precision: 0.2222
# Recall: 0.5000
# ROC AUC: 0.7642
# True Positives: 4, False Negatives: 4, False Positives: 14, True Negatives: 92
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.87      0.91       106
#            1       0.22      0.50      0.31         8
#
#     accuracy                           0.84       114
#    macro avg       0.59      0.68      0.61       114
# weighted avg       0.91      0.84      0.87       114
#
# Days of study for training set: [14 18 20 22 24  7 10 16 26 23 17 11 15 19 25 27 29 31 33 35 37 39 41 45
#  13 21  9 43 47 49]
# Days of study for test set: [10 12 14 16 18  8 13 15 17 19 21 23 27 11 25 29 31 33 35 37 39 20 22 41]
# Percentage of data used for training: 70.16%
# Misclassified instances in fold 49:
#     m_id  day_of_study  true_label  predicted_label
# 16  1284            10           1                0
# 17  1284            13           1                0
# 19  1284            17           1                0
# 21  1284            21           1                0
# 24  1264            11           0                1
# --------------------------------------------------
#
# All Folds Completed.
#
# --------------------------------------------------
#
# Summary of Results:
#
#
# Summary Across Folds:
# Mean accuracy: 0.6618
# Mean F1-macro: 0.4920
# Mean F1-micro: 0.6618
# Mean F1-weighted: 0.6338
# Mean precision: 0.4706
# Mean recall: 0.2102
# Mean ROC AUC: 0.7367
#
# Standard Deviation of F1-macro: 0.1212
# Variance of F1-macro: 0.0147
# Coefficient of Variation of F1-macro: 0.2463
# Dispersion Index of F1-macro: 0.0299
#
# --------------------------------------------------

# %%
# Ensure output directory exists
if not os.path.exists(f"{OUTPUT_DIR}/{split_method}/top_features"):
    os.makedirs(f"{OUTPUT_DIR}/{split_method}/top_features")

# List to store all fold data
all_folds_data = []

# Read and combine feature importances from all folds
for fold in m_data.keys():
    # Load the feature importance file for the current fold
    fold_file = f"{OUTPUT_DIR}/{split_method}/fold_{fold}/top_features.csv"
    if os.path.exists(fold_file):
        fold_data = pd.read_csv(fold_file)
        fold_data['fold'] = fold  # Add fold number for tracking
        all_folds_data.append(fold_data)
    else:
        print(f"File not found for fold {fold}: {fold_file}")

# Combine all fold data into one DataFrame
combined_data = pd.concat(all_folds_data, ignore_index=True)

# Pivot data to include importance per fold as separate columns
importance_per_fold = combined_data.pivot_table(
    index='feature',
    columns='fold',
    values='importance',
    aggfunc='first'
).reset_index()

# Rename fold columns for clarity
importance_per_fold.columns = ['feature'] + [f'Fold_{col}_importance' for col in importance_per_fold.columns if isinstance(col, int)]

# Calculate aggregate metrics for each feature
metrics = combined_data.groupby('feature')['importance'].agg(
    mean_importance='mean',
    std_importance='std'
).reset_index()

# Add variance and coefficient of variation (CV)
metrics['variance'] = metrics['std_importance'] ** 2
metrics['cv'] = metrics['std_importance'] / metrics['mean_importance']

# Merge the fold-level importances with the aggregate metrics
final_table = importance_per_fold.merge(metrics, on='feature', how='left')

# Save the final table to a CSV file
output_file = f"{OUTPUT_DIR}/{split_method}/top_features/aggregated_features_with_folds.csv"
final_table.to_csv(output_file, index=False)

print(f"Aggregated feature importances (including per fold) saved to {output_file}")
# Out:
# Aggregated feature importances (including per fold) saved to output_now_today/grouped_combinations_split_with_sampling/top_features/aggregated_features_with_folds.csv

# %%
# Configuración inicial
TOP_N = 15  # Número de features para la lista corta
CV_THRESHOLD = 1.5  # Umbral para el Coefficient of Variation

# Leer la tabla de features agregadas
aggregated_file = f"{OUTPUT_DIR}/{split_method}/top_features/aggregated_features_with_folds.csv"
features_table = pd.read_csv(aggregated_file)

# Ordenar por Mean Importance
features_table = features_table.sort_values(by="mean_importance", ascending=False)

# Filtrar features consistentes (baja variabilidad)
consistent_features = features_table[features_table['cv'] <= CV_THRESHOLD]

# Generar la lista corta (Top N)
top_features = consistent_features.head(TOP_N)

# Guardar resultados
output_short = f"{OUTPUT_DIR}/{split_method}/top_features/top_{TOP_N}_features.csv"
output_full = f"{OUTPUT_DIR}/{split_method}/top_features/consistent_features.csv"

top_features.to_csv(output_short, index=False)
consistent_features.to_csv(output_full, index=False)

print(f"Top {TOP_N} features saved to: {output_short}")
print(f"Consistent features saved to: {output_full}")
# Out:
# Top 15 features saved to: output_now_today/grouped_combinations_split_with_sampling/top_features/top_15_features.csv
# Consistent features saved to: output_now_today/grouped_combinations_split_with_sampling/top_features/consistent_features.csv

# %%
# Define the output directory and the split method used for organizing results
output_dir = os.path.join(OUTPUT_DIR, SPLIT_METHOD)

# Load input data from the specified configuration file
input_data = pd.read_csv(config.RADIOMICS_FINAL_FEATURES) 

# Initialize containers to collect data for plotting
plot_data = []  # Data for 'day_of_study' histogram
groups_data = []  # Data for 'm_id' histogram

# Iterate through directories to locate and process misclassified data
for dirpath, dirnames, _ in os.walk(output_dir):
    for dirname in dirnames:
        # Check if a top_features file exists in the directory
        top_features_file = os.path.join(output_dir, dirname, 'top_features.csv')
        top_15_features = os.path.join(output_dir, dirname, 'consistent_features.csv')
        # if os.path.exists(top_features_file):
        #     # Load top_features data from the file
        #     top_features_data = pd.read_csv(top_features_file)
        #     # Select features that explain at least 90% of the cumulative importance
        #     cumulative_importance = top_features_data['importance'].cumsum()
        #     selected_features = top_features_data[cumulative_importance <= 0.25]
        #     # Print the selected features for this fold
        #     print(f"Selected features for fold {dirname}, {len(selected_features)} features:")
        #     print(selected_features['feature'].values)
        if os.path.exists(top_15_features):
            # Load top_features data from the file
            top_features_data = pd.read_csv(top_15_features)
            # Print the selected features for this fold
            print(f"Top features for fold {dirname}:")
            print(top_features_data['feature'].values)
# Out:
# Top features for fold top_features:
# ['shape2D_MinorAxisLength'
#  'wavelet-HL_glszm_SizeZoneNonUniformityNormalized'
#  'squareroot_firstorder_Median'
#  'log-sigma-1-0-mm-3D_gldm_DependenceNonUniformityNormalized'
#  'log-sigma-1-0-mm-3D_glszm_SizeZoneNonUniformityNormalized'
#  'shape2D_Elongation' 'shape2D_MaximumDiameter'
#  'log-sigma-3-0-mm-3D_ngtdm_Coarseness' 'wavelet-HH_glcm_SumSquares'
#  'wavelet-HH_glcm_MaximumProbability'
#  'wavelet-HH_glszm_SmallAreaLowGrayLevelEmphasis'
#  'wavelet-HH_glszm_SmallAreaEmphasis' 'logarithm_ngtdm_Strength'
#  'wavelet-LH_firstorder_Kurtosis' 'wavelet-HL_firstorder_90Percentile'
#  'wavelet-HH_firstorder_Kurtosis'
#  'exponential_glrlm_RunLengthNonUniformityNormalized']

# %%
# Read the top features
top_features = pd.read_csv(f"{OUTPUT_DIR}/{split_method}/top_features/top_{TOP_N}_features.csv")

# Prepare data for heatmap: Extract importance values for the top features
heatmap_data = []

for feature in top_features['feature']:
    importance_values = features_table[features_table['feature'] == feature].iloc[:, 1:-4].values.flatten()
    heatmap_data.append(importance_values)

# Convert to DataFrame for better handling
heatmap_df = pd.DataFrame(heatmap_data, columns=[f"Fold_{i}" for i in range(len(importance_values))], index=top_features['feature'].str.split('_').str[-1])

# Plot heatmap 
plt.figure(figsize=(20, 20))  # Ajustar tamaño de la figura
sns.heatmap(heatmap_df, 
            annot=True, 
            cmap="YlGnBu", 
            cbar_kws={'label': 'Importance'}, 
            fmt='.4f', 
            annot_kws={"size": 6})  # Tamaño de texto más pequeño

# Ajustar etiquetas del eje Y
plt.yticks(rotation=0, fontsize=8)  # Etiquetas de Y horizontales
plt.xticks(rotation=45, fontsize=8, ha='right')  # Inclinación de etiquetas de X

# Ajustar título y etiquetas
plt.title("Feature Importance Evolution Across Folds (Heatmap)", fontsize=12)
plt.xlabel("Fold", fontsize=10)
plt.ylabel("Feature", fontsize=10)

plt.tight_layout()  # Ajuste automático de márgenes
plt.show()
