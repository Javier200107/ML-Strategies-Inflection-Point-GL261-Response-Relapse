# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, roc_curve, auc
import xgboost as xgb 
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from src.processing import Processing
import config
from sklearn.feature_selection import SelectKBest, chi2
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import pandas as pd
import numpy as np
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
import warnings
from src.datasplitting import DataSplitting
warnings.filterwarnings('ignore')
from sklearn.model_selection import GridSearchCV, PredefinedSplit, TimeSeriesSplit
from sklearn.metrics import (
    accuracy_score, f1_score, precision_score, recall_score,
    confusion_matrix, roc_auc_score, precision_recall_curve, auc, classification_report
)
from src.processing import Processing
from sklearn.metrics import roc_curve, precision_recall_curve, average_precision_score
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import xgboost as xgb
from imblearn.over_sampling import SMOTE
from collections import Counter
from src.balance import split_data_nested_cv_ts, split_data, drop_mice_group, balance_classes_by_undersampling, balance_classes_by_undersampling_features_and_target, balance_before_merge, oversample_and_merge, ensemble_sample_and_merge

# %%
# Step 1: Load and preprocess the data
dataclass = Processing(source_path=config.RADIOMICS_FINAL_FEATURES, all_features=False)
dataclass.read()
# df = dataclass.preprocess()  # Assume this keeps mouse IDs for splitting
df = dataclass.df
DS_LENGTH = len(df)
# Out:
# WARNING:root:Columns ['i', 'n', 'p', 'u', 't', '\\', 'f', 'e', 'a', 't', 'u', 'r', 'e', 's', '\\', 'r', 'a', 'd', 'i', 'o', 'm', 'i', 'c', 's', '_', 'f', 'i', 'n', 'a', 'l', '_', 'f', 'e', 'a', 't', 'u', 'r', 'e', 's', '_', 'n', 'o', '_', 'f', 'i', 'l', 't', 'e', 'r', 's', '.', 'c', 's', 'v'] are not in the dataset

# %%
N_SPLITS = 5
TEST_SIZE = 0.3 
SEED = 42
SAMPLE_SIZE = 10
TOP_FEATURES = 15

# Hyperparameter grid for XGBClassifier
PARAM_GRID = {
    'xgbclassifier__n_estimators': [100, 500, 1000],
    'xgbclassifier__learning_rate': [0.01, 0.05, 0.1],
    'xgbclassifier__max_depth': [3, 4, 5, 7],
    'xgbclassifier__subsample': [0.6, 0.7, 0.8, 1.0],
    'xgbclassifier__min_child_weight': [1, 5, 10],
    'xgbclassifier__gamma': [0.5, 1, 1.5, 2, 5],
    'xgbclassifier__colsample_bytree': [0.6, 0.8, 1.0]
}
xgb_params = {
    'xgbclassifier__colsample_bytree': 0.6,
    'xgbclassifier__gamma': 0.5,
    'xgbclassifier__learning_rate': 0.01,
    'xgbclassifier__max_depth': 3,
    'xgbclassifier__min_child_weight': 1,
    'xgbclassifier__n_estimators': 100,
    'xgbclassifier__subsample': 0.6
}
OUTPUT_DIR = 'output'

# %%
def train_test_and_show_results(split_method: str, m_data: dict, plot_feature_importances_per_fold: bool = True, plot_roc_and_feature_importances: bool = True, show_fold_results: bool = True,
                                tune_hyperparameters: bool = False, param_grid: dict = None, xgb_params: dict = None, show_label: bool = True):

    # Track results for each fold
    fold_accuracies, fold_f1_macros, fold_precisions, fold_recalls, fold_roc_aucs, fold_f1_micros, fold_f1_weighted, feature_importances, true_positives, false_positives, true_negatives, false_negatives  = [], [], [], [], [], [], [], [], [], [], [], []

    best_params_per_fold = []  # Track best parameters per fold

    # Store ROC curve points for all folds
    roc_curves = []

    for fold, split_data in m_data.items():
        print(f"\nFold {fold}:")
        print(f"Original train class distribution: {Counter(split_data['y_train'])}")
        print(f"Original test class distribution: {Counter(split_data['y_test'])}") 
        
        # Check if directory exists
        if not os.path.exists(f"{OUTPUT_DIR}/{split_method}/fold_{fold}"):
            os.makedirs(f"{OUTPUT_DIR}/{split_method}/fold_{fold}")

        # Keep `m_id` for analysis later
        m_id_test = split_data['X_test']['m_id']  # Save `m_id` for test
        day_of_study_test = split_data['X_test']['day_of_study']  # Save `day_of_study` for test

        # Exclude `m_id` and `day_of_study` for training
        X_train = split_data['X_train'].drop(columns=['m_id', 'day_of_study'])
        X_test = split_data['X_test'].drop(columns=['m_id', 'day_of_study'])

        # Get feature names
        feature_names = X_train.columns.str.replace('original_', '', regex=False)

        if tune_hyperparameters:

            # Define the model with hyperparameter tuning
            model = Pipeline([
                ('scaler', StandardScaler()), 
                ('smote', SMOTE(k_neighbors=5, random_state=SEED)),
                ('xgbclassifier', xgb.XGBClassifier(random_state=SEED))
            ])

            grid_search = GridSearchCV(model, param_grid=param_grid, cv=TimeSeriesSplit(n_splits=5), scoring='f1_macro', n_jobs=-1)
            grid_search.fit(X_train, split_data['y_train'])
            best_model = grid_search.best_estimator_
            best_params = grid_search.best_params_
            best_params_per_fold.append(best_params)  # Save best parameters
            print(f"Best parameters for fold {fold}: {best_params}")
        else:
            # Use provided xgb_params or default parameters if not tuning
            model = Pipeline([
                ('scaler', StandardScaler()), 
                ('smote', SMOTE(k_neighbors=5, random_state=SEED)),
                ('xgbclassifier', xgb.XGBClassifier(**(xgb_params or {}), random_state=SEED)),
            ])
            
            model.fit(X_train, split_data['y_train'])
            best_model = model        

        # Extract feature importances from XGBoost
        xgb_model = best_model.named_steps['xgbclassifier']
        importances = xgb_model.feature_importances_

        # Evaluate on the test set
        preds = best_model.predict(X_test)
        preds_proba = best_model.predict_proba(X_test)[:, 1]  # Probability for the positive class
        
        # Calculate metrics
        accuracy = accuracy_score(split_data['y_test'], preds)
        f1_macro = f1_score(split_data['y_test'], preds, average='macro')
        f1_micro = f1_score(split_data['y_test'], preds, average='micro')
        f1_weighted = f1_score(split_data['y_test'], preds, average='weighted')
        precision = precision_score(split_data['y_test'], preds,zero_division=1)
        recall = recall_score(split_data['y_test'], preds, zero_division=1)

        fpr, tpr, _ = roc_curve(split_data['y_test'], preds_proba, pos_label=1)
        roc_auc = auc(fpr, tpr)

        # If auc is NaN and precision or recall is 1, set auc to 1, else set to 0
        if np.isnan(roc_auc) and (precision == 1 or recall == 1):
            roc_auc = 1
        elif np.isnan(roc_auc):
            roc_auc = 0
                
        roc_curves.append((fpr, tpr))

        # Calculate the confusion matrix
        cm = confusion_matrix(split_data['y_test'], preds)

        # Handle cases where the confusion matrix shape is unexpected
        if cm.shape == (1, 1):  # Only one class present
            tn, fp, fn, tp = (cm[0, 0], 0, 0, 0) if split_data['y_test'].iloc[0] == 0 else (0, 0, 0, cm[0, 0])
        elif cm.shape == (1, 2):  # One class is missing in y_test
            tn, fp, fn, tp = (cm[0, 0], cm[0, 1], 0, 0)
        elif cm.shape == (2, 1):  # One class is missing in preds
            tn, fp, fn, tp = (0, 0, cm[1, 0], cm[0, 0])
        else:  # Normal case with both classes present
            tn  , fp, fn, tp = cm.ravel()

         # Identify misclassified instances
        misclassified_mask = split_data['y_test'] != preds
        misclassified = pd.DataFrame({
            'm_id': m_id_test[misclassified_mask],
            'day_of_study': day_of_study_test[misclassified_mask],
            'true_label': split_data['y_test'][misclassified_mask],
            'predicted_label': preds[misclassified_mask]
        })
        # Save misclassified instances for this fold
        misclassified.to_csv(f"{OUTPUT_DIR}/{split_method}/fold_{fold}/misclassified.csv", index=False)

        if show_fold_results:
            # Print fold results
            print(f"\n\nFold {fold} results:")
            print(f"Accuracy: {accuracy:.4f}")
            print(f"F1-macro: {f1_macro:.4f}")
            print(f"F1-micro: {f1_micro:.4f}")
            print(f"F1-weighted: {f1_weighted:.4f}")
            print(f"Precision: {precision:.4f}")
            print(f"Recall: {recall:.4f}")
            print(f"ROC AUC: {roc_auc:.4f}")
            print(f"True Positives: {tp}, False Negatives: {fn}, False Positives: {fp}, True Negatives: {tn}")
            print(f"Classification report:\n{classification_report(split_data['y_test'], preds)}")

            print(f"Days of study for training set: {split_data['X_train']['day_of_study'].unique()}")
            print(f"Days of study for test set: {split_data['X_test']['day_of_study'].unique()}")
            print(f"Percentage of data used for training: {len(split_data['X_train']) / DS_LENGTH * 100:.2f}%")

            print(f"Misclassified instances in fold {fold}:")
            print(misclassified[['m_id', 'day_of_study', 'true_label', 'predicted_label']].head())

            print("-" * 50)
        
        if plot_feature_importances_per_fold:
            # Plot top k features for this fold
            top_indices = np.argsort(importances)[-TOP_FEATURES:][::-1]
            top_importances = importances[top_indices]

            plt.figure(figsize=(12, 4))
            plt.subplot(1, 2, 1)
            plt.barh(range(TOP_FEATURES), top_importances, color='skyblue', align='center')
            plt.yticks(range(TOP_FEATURES), feature_names[top_indices], ha="right")
            plt.ylabel("Feature Index")
            plt.xlabel("Importance")
            plt.title(f"Top {TOP_FEATURES} Feature Importances (Fold {fold})")
            # Plot confusion matrix
            plt.subplot(1, 2, 2)
            cm = confusion_matrix(split_data['y_test'], preds)
            sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
            plt.title(f'Confusion Matrix (Fold {fold})')
            plt.xlabel('Predicted Label')
            plt.ylabel('True Label')
            plt.tight_layout()
            plt.show()

        # Track results
        fold_accuracies.append(accuracy)
        fold_f1_macros.append(f1_macro)
        fold_f1_micros.append(f1_micro)
        fold_f1_weighted.append(f1_weighted)
        fold_precisions.append(precision)
        fold_recalls.append(recall)
        fold_roc_aucs.append(roc_auc)
        feature_importances.append(importances)
        true_positives.append(tp)
        false_negatives.append(fn)
        false_positives.append(fp)
        true_negatives.append(tn)

        # Save fold metrics to a CSV file
        fold_metrics = pd.DataFrame({
            'accuracy': [accuracy],
            'f1_macro': [f1_macro],
            'f1_micro': [f1_micro],
            'f1_weighted': [f1_weighted],
            'precision': [precision],
            'recall': [recall],
            'roc_auc': [roc_auc],
            'true_positives': [tp],
            'false_negatives': [fn],
            'false_positives': [fp],
            'true_negatives': [tn],
            'days_of_study_in_train': [split_data['X_train']['day_of_study'].unique()],
            'days_of_study_in_test': [split_data['X_test']['day_of_study'].unique()],
            'percentage_of_data_in_train': [len(split_data['X_train']) / DS_LENGTH * 100],
            'percentage_of_data_in_test': [len(split_data['X_test']) / DS_LENGTH * 100]
        })

        fold_metrics.to_csv(f"{OUTPUT_DIR}/{split_method}/fold_{fold}/metrics.csv", index=False)

        # Save top 15 feature importances to a csv file
        # top_indices = np.argsort(importances)[-TOP_FEATURES:][::-1]
        top_indices = np.argsort(importances)[::-1]
        top_importances = importances[top_indices]
        top_features = pd.DataFrame({
            'feature': feature_names[top_indices],
            'importance': top_importances
        })

        top_features.to_csv(f"{OUTPUT_DIR}/{split_method}/fold_{fold}/top_features.csv", index=False)

    print(f"\nAll Folds Completed.") 
    print("\n--------------------------------------------------")
    print("\nSummary of Results:\n")

    # Display best parameters summary
    if tune_hyperparameters:
        print("\nBest parameters per fold:")
        for fold, params in enumerate(best_params_per_fold):
            print(f"Fold {fold}: {params}")

    # Calculate mean importances across folds
    mean_importances = np.mean(feature_importances, axis=0)
    # Get indices of the top k features by mean
    top_indices_mean = np.argsort(mean_importances)[-TOP_FEATURES:][::-1]
    top_importances_mean = mean_importances[top_indices_mean]
    
    if plot_roc_and_feature_importances:

        # Plotting ROC curve side by side
        plt.figure(figsize=(15, 5))

        # ROC Curve Plot
        plt.subplot(1, 2, 1)  # First plot (1 row, 2 columns, 1st plot)
        if show_label:
            for i, (fpr, tpr) in enumerate(roc_curves):
                plt.plot(fpr, tpr, label=f'Fold {i} (ROC AUC = {fold_roc_aucs[i]:.2f})')
        else:
            for i, (fpr, tpr) in enumerate(roc_curves):
                plt.plot(fpr, tpr)
        plt.plot([0, 1], [0, 1], 'k--', label="Random Classifier")
        plt.title("ROC Curve Across Folds")
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.legend(loc="lower right")

        plt.subplot(1, 2, 2)  # Second plot (1 row, 2 columns, 2nd plot)
        plt.barh(range(TOP_FEATURES), top_importances_mean, color='skyblue', align='center')
        plt.yticks(range(TOP_FEATURES), feature_names[top_indices_mean])
        plt.ylabel("Feature Index")
        plt.xlabel("Importance")
        plt.title(f"Top {TOP_FEATURES} Feature Importances (Mean)")

        # Display the plots side by side
        plt.tight_layout()  # Adjust layout for better spacing
        plt.show()

    # Display summary statistics across folds
    print(f"\nSummary Across Folds:")
    print(f"Mean accuracy: {np.mean(fold_accuracies):.4f}")
    print(f"Mean F1-macro: {np.mean(fold_f1_macros):.4f}")
    print(f"Mean F1-micro: {np.mean(fold_f1_micros):.4f}")
    print(f"Mean F1-weighted: {np.mean(fold_f1_weighted):.4f}")
    print(f"Mean precision: {np.mean(fold_precisions):.4f}")
    print(f"Mean recall: {np.mean(fold_recalls):.4f}")
    print(f"Mean ROC AUC: {np.mean(fold_roc_aucs):.4f}")

    # Standard deviation, variance, coefficient of variation and dispersion index of f1_macro
    print(f"\nStandard Deviation of F1-macro: {np.std(fold_f1_macros):.4f}")
    print(f"Variance of F1-macro: {np.var(fold_f1_macros):.4f}")
    print(f"Coefficient of Variation of F1-macro: {np.std(fold_f1_macros) / np.mean(fold_f1_macros):.4f}")
    print(f"Dispersion Index of F1-macro: {np.var(fold_f1_macros) / np.mean(fold_f1_macros):.4f}")

    print("\n--------------------------------------------------")

    # Save summary statistics to a CSV file
    summary_metrics = pd.DataFrame({
        'accuracy': [np.mean(fold_accuracies)],
        'f1_macro': [np.mean(fold_f1_macros)],
        'f1_micro': [np.mean(fold_f1_micros)],
        'f1_weighted': [np.mean(fold_f1_weighted)],
        'precision': [np.mean(fold_precisions)],
        'recall': [np.mean(fold_recalls)],
        'roc_auc': [np.mean(fold_roc_aucs)],
        'std_f1_macro': [np.std(fold_f1_macros)],
        'var_f1_macro': [np.var(fold_f1_macros)],
        'cv_f1_macro': [np.std(fold_f1_macros) / np.mean(fold_f1_macros)],
        'di_f1_macro': [np.var(fold_f1_macros) / np.mean(fold_f1_macros)]
    })

    summary_metrics.to_csv(f"{OUTPUT_DIR}/{split_method}/summary_metrics.csv", index=False)

    # Save top feature importances and split method in a csv file
    top_features = pd.DataFrame({
        'feature': feature_names[top_indices_mean],
        'importance': top_importances_mean
    })

    top_features.to_csv(f"{OUTPUT_DIR}/{split_method}/top_features.csv", index=False) 

    # Optional: Calculate the most common parameters across folds
    if tune_hyperparameters:
        most_comon_params = max(set(best_params_per_fold), key=best_params_per_fold.count)
        print("\nMost common parameters across folds:")
        print(most_comon_params)

# %%
split_method, m_data = DataSplitting.split_population_informed_combinations(df=df, seed=SEED, sample_size=50, test_size=TEST_SIZE)

train_test_and_show_results(split_method=split_method, m_data=m_data, plot_feature_importances_per_fold=False, tune_hyperparameters=False, plot_roc_and_feature_importances=False, xgb_params=xgb_params)
# Out:
# Total possible combinations: 8568
# Number of sampled combinations: 50
#
# Fold 0:
# Original train class distribution: Counter({0: 208, 1: 54})
# Original test class distribution: Counter({0: 108, 1: 12})
#
#
# Fold 0 results:
# Accuracy: 0.8167
# F1-macro: 0.6034
# F1-micro: 0.8167
# F1-weighted: 0.8361
# Precision: 0.2500
# Recall: 0.4167
# ROC AUC: 0.8148
# True Positives: 5, False Negatives: 7, False Positives: 15, True Negatives: 93
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.86      0.89       108
#            1       0.25      0.42      0.31        12
#
#     accuracy                           0.82       120
#    macro avg       0.59      0.64      0.60       120
# weighted avg       0.86      0.82      0.84       120
#
# Days of study for training set: [10 12 14 16 18  8 20 22 24 26 23 17 11 15 19 25 27 29 31 33 35 37 39 41
#  45 13 21  9 43 47 49]
# Days of study for test set: [14 18 20 22 24  7 11 16 10 13 15 17 19 21 23 27 25 29 31 33 35 37 39 41]
# Percentage of data used for training: 68.59%
# Misclassified instances in fold 0:
#     m_id  day_of_study  true_label  predicted_label
# 0   1258            14           0                1
# 7   1258             7           0                1
# 8   1258             7           0                1
# 10  1359            14           0                1
# 18  1281            10           1                0
# --------------------------------------------------
#
# Fold 1:
# Original train class distribution: Counter({0: 236, 1: 54})
# Original test class distribution: Counter({0: 80, 1: 12})
#
#
# Fold 1 results:
# Accuracy: 0.8804
# F1-macro: 0.6008
# F1-micro: 0.8804
# F1-weighted: 0.8477
# Precision: 0.6667
# Recall: 0.1667
# ROC AUC: 0.8240
# True Positives: 2, False Negatives: 10, False Positives: 1, True Negatives: 79
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.93        80
#            1       0.67      0.17      0.27        12
#
#     accuracy                           0.88        92
#    macro avg       0.78      0.58      0.60        92
# weighted avg       0.86      0.88      0.85        92
#
# Days of study for training set: [10 14 16 18 20 22 24 26 23 17 11 15 19 25 27 29 31 33 35 37 39 41 45 13
#  21  9 43 47 49]
# Days of study for test set: [14 18 20 22 24  7 10 12 16  8 11 13 15 17 19 21 23 27 25 29 31 33 35 37]
# Percentage of data used for training: 75.92%
# Misclassified instances in fold 1:
#     m_id  day_of_study  true_label  predicted_label
# 19  1260            16           0                1
# 37  1281            10           1                0
# 38  1281            13           1                0
# 39  1281            15           1                0
# 40  1281            17           1                0
# --------------------------------------------------
#
# Fold 2:
# Original train class distribution: Counter({0: 209, 1: 54})
# Original test class distribution: Counter({0: 107, 1: 12})
#
#
# Fold 2 results:
# Accuracy: 0.8403
# F1-macro: 0.6477
# F1-micro: 0.8403
# F1-weighted: 0.8557
# Precision: 0.3158
# Recall: 0.5000
# ROC AUC: 0.8497
# True Positives: 6, False Negatives: 6, False Positives: 13, True Negatives: 94
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91       107
#            1       0.32      0.50      0.39        12
#
#     accuracy                           0.84       119
#    macro avg       0.63      0.69      0.65       119
# weighted avg       0.88      0.84      0.86       119
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 17 11 15 19 23 25 27 29 31 33 35 37 39 41
#  45 13 21  9 43 47]
# Days of study for test set: [10 14 16 18 20 22 24 26 23 13 15 17 19 21 27 25 29 31 33 35 37 11 39 41
#  43 45 47 49]
# Percentage of data used for training: 68.85%
# Misclassified instances in fold 2:
#     m_id  day_of_study  true_label  predicted_label
# 0   1261            10           0                1
# 21  1281            10           1                0
# 23  1281            15           1                0
# 24  1281            17           1                0
# 27  1281            19           1                0
# --------------------------------------------------
#
# Fold 3:
# Original train class distribution: Counter({0: 214, 1: 33})
# Original test class distribution: Counter({0: 102, 1: 33})
#
#
# Fold 3 results:
# Accuracy: 0.7407
# F1-macro: 0.5333
# F1-micro: 0.7407
# F1-weighted: 0.6923
# Precision: 0.4167
# Recall: 0.1515
# ROC AUC: 0.6839
# True Positives: 5, False Negatives: 28, False Positives: 7, True Negatives: 95
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84       102
#            1       0.42      0.15      0.22        33
#
#     accuracy                           0.74       135
#    macro avg       0.59      0.54      0.53       135
# weighted avg       0.69      0.74      0.69       135
#
# Days of study for training set: [14 18 20 22 24  7 10 16 26 23 17 11 13 15 19 21 27 25 29 31  9 33 35 37
#  39 41 43 45 47 49]
# Days of study for test set: [10 12 14 16 18  8 11 15 17 19 23 25 27 29 31 33 35 37 39 41 45 13 21]
# Percentage of data used for training: 64.66%
# Misclassified instances in fold 3:
#     m_id  day_of_study  true_label  predicted_label
# 16  1276            11           1                0
# 17  1276            15           1                0
# 19  1276            17           1                0
# 21  1276            19           1                0
# 22  1276            23           1                0
# --------------------------------------------------
#
# Fold 4:
# Original train class distribution: Counter({0: 248, 1: 50})
# Original test class distribution: Counter({0: 68, 1: 16})
#
#
# Fold 4 results:
# Accuracy: 0.8333
# F1-macro: 0.6027
# F1-micro: 0.8333
# F1-weighted: 0.7901
# Precision: 0.7500
# Recall: 0.1875
# ROC AUC: 0.8989
# True Positives: 3, False Negatives: 13, False Positives: 1, True Negatives: 67
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91        68
#            1       0.75      0.19      0.30        16
#
#     accuracy                           0.83        84
#    macro avg       0.79      0.59      0.60        84
# weighted avg       0.82      0.83      0.79        84
#
# Days of study for training set: [14 18 20 22 24  7 10 16 26 23 17 11 15 19 25 27 29 31 33 35 37 39 41 45
#  13 21  9 43 47 49]
# Days of study for test set: [10 12 14 16 18  8 11 13 15 17 19 21 23 27 25 29 31 33 35 37]
# Percentage of data used for training: 78.01%
# Misclassified instances in fold 4:
#     m_id  day_of_study  true_label  predicted_label
# 16  1359            11           0                1
# 25  1284            10           1                0
# 26  1284            13           1                0
# 27  1284            15           1                0
# 28  1284            17           1                0
# --------------------------------------------------
#
# Fold 5:
# Original train class distribution: Counter({0: 221, 1: 37})
# Original test class distribution: Counter({0: 95, 1: 29})
#
#
# Fold 5 results:
# Accuracy: 0.7258
# F1-macro: 0.5976
# F1-micro: 0.7258
# F1-weighted: 0.7185
# Precision: 0.4000
# Recall: 0.3448
# ROC AUC: 0.6207
# True Positives: 10, False Negatives: 19, False Positives: 15, True Negatives: 80
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.82        95
#            1       0.40      0.34      0.37        29
#
#     accuracy                           0.73       124
#    macro avg       0.60      0.59      0.60       124
# weighted avg       0.71      0.73      0.72       124
#
# Days of study for training set: [10 12 14 16 18  8 20 22 24 26 23 17 11 15 19 25 27 29 31 33 35 37 39 41
#  45 13 21 43 47]
# Days of study for test set: [14 18 20 22 24  7 10 13 15 17 19 21 23 27 25 29 31  9 11 33 35 37 39 41
#  43 45 47 49]
# Percentage of data used for training: 67.54%
# Misclassified instances in fold 5:
#     m_id  day_of_study  true_label  predicted_label
# 0   1258            14           0                1
# 9   1281            10           1                0
# 10  1281            13           1                0
# 11  1281            15           1                0
# 12  1281            17           1                0
# --------------------------------------------------
#
# Fold 6:
# Original train class distribution: Counter({0: 227, 1: 45})
# Original test class distribution: Counter({0: 89, 1: 21})
#
#
# Fold 6 results:
# Accuracy: 0.7545
# F1-macro: 0.5614
# F1-micro: 0.7545
# F1-weighted: 0.7413
# Precision: 0.3125
# Recall: 0.2381
# ROC AUC: 0.7223
# True Positives: 5, False Negatives: 16, False Positives: 11, True Negatives: 78
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85        89
#            1       0.31      0.24      0.27        21
#
#     accuracy                           0.75       110
#    macro avg       0.57      0.56      0.56       110
# weighted avg       0.73      0.75      0.74       110
#
# Days of study for training set: [10 12 14 16 18  8 20 22 24 26 23 17 11 13 15 19 21 27 25 29 31  9 33 35
#  37 39 41 43 45 47 49]
# Days of study for test set: [14 18 20 22 24  7 11 16 15 17 19 23 25 27 29 31 33 35 37 39 41 45 21 43
#  47]
# Percentage of data used for training: 71.20%
# Misclassified instances in fold 6:
#     m_id  day_of_study  true_label  predicted_label
# 0   1258            14           0                1
# 7   1258             7           0                1
# 8   1258             7           0                1
# 9   1359            11           0                1
# 10  1359            14           0                1
# --------------------------------------------------
#
# Fold 7:
# Original train class distribution: Counter({0: 296, 1: 41})
# Original test class distribution: Counter({1: 25, 0: 20})
#
#
# Fold 7 results:
# Accuracy: 0.4222
# F1-macro: 0.3500
# F1-micro: 0.4222
# F1-weighted: 0.3259
# Precision: 0.4000
# Recall: 0.0800
# ROC AUC: 0.6720
# True Positives: 2, False Negatives: 23, False Positives: 3, True Negatives: 17
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.42      0.85      0.57        20
#            1       0.40      0.08      0.13        25
#
#     accuracy                           0.42        45
#    macro avg       0.41      0.46      0.35        45
# weighted avg       0.41      0.42      0.33        45
#
# Days of study for training set: [10 12 14 16 18  8 20 22 24 26 23 11 15 17 19 25 27 29 31 33 35 37 39 41
#  45 13 21 43 47 49]
# Days of study for test set: [14 18 20 22 24  7 17 11 16 15 19 21 23 25 27 29 31  9]
# Percentage of data used for training: 88.22%
# Misclassified instances in fold 7:
#     m_id  day_of_study  true_label  predicted_label
# 0   1258            14           0                1
# 7   1258             7           0                1
# 11  1359            11           0                1
# 20  1285            15           1                0
# 21  1285            15           1                0
# --------------------------------------------------
#
# Fold 8:
# Original train class distribution: Counter({0: 213, 1: 58})
# Original test class distribution: Counter({0: 103, 1: 8})
#
#
# Fold 8 results:
# Accuracy: 0.7658
# F1-macro: 0.5690
# F1-micro: 0.7658
# F1-weighted: 0.8182
# Precision: 0.1786
# Recall: 0.6250
# ROC AUC: 0.8192
# True Positives: 5, False Negatives: 3, False Positives: 23, True Negatives: 80
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.78      0.86       103
#            1       0.18      0.62      0.28         8
#
#     accuracy                           0.77       111
#    macro avg       0.57      0.70      0.57       111
# weighted avg       0.91      0.77      0.82       111
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 11 15 17 19 25 27 29 31 33 35 37 39
#  41 45 13 21  9 43 47]
# Days of study for test set: [17 11 14 16 18 20 22 10 13 15 19 21 23 27 25 29 31 33 35 37 39 41 43 45
#  47 49]
# Percentage of data used for training: 70.94%
# Misclassified instances in fold 8:
#     m_id  day_of_study  true_label  predicted_label
# 4   1360            16           0                1
# 17  1284            10           1                0
# 18  1284            13           1                0
# 20  1284            17           1                0
# 26  1264            11           0                1
# --------------------------------------------------
#
# Fold 9:
# Original train class distribution: Counter({0: 201, 1: 58})
# Original test class distribution: Counter({0: 115, 1: 8})
#
#
# Fold 9 results:
# Accuracy: 0.8699
# F1-macro: 0.6306
# F1-micro: 0.8699
# F1-weighted: 0.8893
# Precision: 0.2500
# Recall: 0.5000
# ROC AUC: 0.8109
# True Positives: 4, False Negatives: 4, False Positives: 12, True Negatives: 103
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93       115
#            1       0.25      0.50      0.33         8
#
#     accuracy                           0.87       123
#    macro avg       0.61      0.70      0.63       123
# weighted avg       0.92      0.87      0.89       123
#
# Days of study for training set: [10 14 16 18 20 22 24 26 23 17 11 15 19 25 27 29 31 33 35 37 39 41 45 13
#  21  9 43 47 49]
# Days of study for test set: [14 18 20 22 24  7 10 12 16  8 13 15 17 19 21 23 27 11 25 29 31 33 35 37
#  39 41]
# Percentage of data used for training: 67.80%
# Misclassified instances in fold 9:
#     m_id  day_of_study  true_label  predicted_label
# 25  1284            10           1                0
# 26  1284            13           1                0
# 27  1284            15           1                0
# 28  1284            17           1                0
# 33  1264            11           0                1
# --------------------------------------------------
#
# Fold 10:
# Original train class distribution: Counter({0: 248, 1: 37})
# Original test class distribution: Counter({0: 68, 1: 29})
#
#
# Fold 10 results:
# Accuracy: 0.6907
# F1-macro: 0.5726
# F1-micro: 0.6907
# F1-weighted: 0.6629
# Precision: 0.4706
# Recall: 0.2759
# ROC AUC: 0.6592
# True Positives: 8, False Negatives: 21, False Positives: 9, True Negatives: 59
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.87      0.80        68
#            1       0.47      0.28      0.35        29
#
#     accuracy                           0.69        97
#    macro avg       0.60      0.57      0.57        97
# weighted avg       0.66      0.69      0.66        97
#
# Days of study for training set: [10 14 16 18 20 22 24 26 23 17 11 15 19 25 27 29 31 33 35 37 39 41 45 13
#  21 43 47]
# Days of study for test set: [14 18 20 22 24  7 10 12 16  8 13 15 17 19 21 23 27 25 29 31  9 11 33 35
#  37 39 41 43 45 47 49]
# Percentage of data used for training: 74.61%
# Misclassified instances in fold 10:
#     m_id  day_of_study  true_label  predicted_label
# 0   1258            14           0                1
# 7   1258             7           0                1
# 25  1281            10           1                0
# 27  1281            15           1                0
# 28  1281            17           1                0
# --------------------------------------------------
#
# Fold 11:
# Original train class distribution: Counter({0: 195, 1: 54})
# Original test class distribution: Counter({0: 121, 1: 12})
#
#
# Fold 11 results:
# Accuracy: 0.8647
# F1-macro: 0.5878
# F1-micro: 0.8647
# F1-weighted: 0.8647
# Precision: 0.2500
# Recall: 0.2500
# ROC AUC: 0.8072
# True Positives: 3, False Negatives: 9, False Positives: 9, True Negatives: 112
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       121
#            1       0.25      0.25      0.25        12
#
#     accuracy                           0.86       133
#    macro avg       0.59      0.59      0.59       133
# weighted avg       0.86      0.86      0.86       133
#
# Days of study for training set: [14 18 20 22 24  7 10 16 26 23 17 11 15 19 25 27 29 31 33 35 37 39 41 45
#  13 21  9 43 47 49]
# Days of study for test set: [10 12 14 16 18  8 11 20 22 13 15 17 19 21 23 27 25 29 31 33 35 37 39 41]
# Percentage of data used for training: 65.18%
# Misclassified instances in fold 11:
#     m_id  day_of_study  true_label  predicted_label
# 0   1260            10           0                1
# 18  1360            16           0                1
# 31  1281            10           1                0
# 32  1281            13           1                0
# 33  1281            15           1                0
# --------------------------------------------------
#
# Fold 12:
# Original train class distribution: Counter({0: 171, 1: 58})
# Original test class distribution: Counter({0: 145, 1: 8})
#
#
# Fold 12 results:
# Accuracy: 0.7974
# F1-macro: 0.5635
# F1-micro: 0.7974
# F1-weighted: 0.8496
# Precision: 0.1515
# Recall: 0.6250
# ROC AUC: 0.8060
# True Positives: 5, False Negatives: 3, False Positives: 28, True Negatives: 117
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.81      0.88       145
#            1       0.15      0.62      0.24         8
#
#     accuracy                           0.80       153
#    macro avg       0.56      0.72      0.56       153
# weighted avg       0.93      0.80      0.85       153
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 17 11 15 19 25 27 29 31 33 35 37 39
#  41 45 13 21  9 43 47]
# Days of study for test set: [11 14 16 18 20 10 13 15 17 19 21 23 27 25 29 31 33 35 37 39 22 41 43 45
#  47 49]
# Percentage of data used for training: 59.95%
# Misclassified instances in fold 12:
#     m_id  day_of_study  true_label  predicted_label
# 0   1361            11           0                1
# 2   1361            16           0                1
# 3   1361            16           0                1
# 12  1284            10           1                0
# 13  1284            13           1                0
# --------------------------------------------------
#
# Fold 13:
# Original train class distribution: Counter({0: 256, 1: 46})
# Original test class distribution: Counter({0: 60, 1: 20})
#
#
# Fold 13 results:
# Accuracy: 0.7125
# F1-macro: 0.5399
# F1-micro: 0.7125
# F1-weighted: 0.6808
# Precision: 0.3636
# Recall: 0.2000
# ROC AUC: 0.6708
# True Positives: 4, False Negatives: 16, False Positives: 7, True Negatives: 53
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.88      0.82        60
#            1       0.36      0.20      0.26        20
#
#     accuracy                           0.71        80
#    macro avg       0.57      0.54      0.54        80
# weighted avg       0.67      0.71      0.68        80
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 11 15 17 19 25 27 29 31 33 35 37 39
#  41 45 21  9 43 47]
# Days of study for test set: [17 11 14 16 18 20 22 10 13 15 19 21 23 27 25 29 31 33 35 37 39 41 43 45
#  47 49]
# Percentage of data used for training: 79.06%
# Misclassified instances in fold 13:
#     m_id  day_of_study  true_label  predicted_label
# 4   1360            16           0                1
# 17  1281            10           1                0
# 18  1281            13           1                0
# 19  1281            15           1                0
# 20  1281            17           1                0
# --------------------------------------------------
#
# Fold 14:
# Original train class distribution: Counter({0: 192, 1: 45})
# Original test class distribution: Counter({0: 124, 1: 21})
#
#
# Fold 14 results:
# Accuracy: 0.7448
# F1-macro: 0.6159
# F1-micro: 0.7448
# F1-weighted: 0.7740
# Precision: 0.3000
# Recall: 0.5714
# ROC AUC: 0.7627
# True Positives: 12, False Negatives: 9, False Positives: 28, True Negatives: 96
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.77      0.84       124
#            1       0.30      0.57      0.39        21
#
#     accuracy                           0.74       145
#    macro avg       0.61      0.67      0.62       145
# weighted avg       0.83      0.74      0.77       145
#
# Days of study for training set: [14 18 20 22 24  7 10 16 26 23 17 11 13 15 19 21 27 25 29 31  9 33 35 37
#  39 41 43 45 47 49]
# Days of study for test set: [10 12 14 16 18  8 11 15 17 19 23 25 27 29 31 33 35 37 39 41 45 21 43 47]
# Percentage of data used for training: 62.04%
# Misclassified instances in fold 14:
#     m_id  day_of_study  true_label  predicted_label
# 0   1260            10           0                1
# 3   1260            12           0                1
# 10  1260            16           0                1
# 14  1260             8           0                1
# 16  1359            11           0                1
# --------------------------------------------------
#
# Fold 15:
# Original train class distribution: Counter({0: 202, 1: 45})
# Original test class distribution: Counter({0: 114, 1: 21})
#
#
# Fold 15 results:
# Accuracy: 0.8074
# F1-macro: 0.5391
# F1-micro: 0.8074
# F1-weighted: 0.7814
# Precision: 0.2727
# Recall: 0.1429
# ROC AUC: 0.7377
# True Positives: 3, False Negatives: 18, False Positives: 8, True Negatives: 106
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89       114
#            1       0.27      0.14      0.19        21
#
#     accuracy                           0.81       135
#    macro avg       0.56      0.54      0.54       135
# weighted avg       0.76      0.81      0.78       135
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 17 11 13 15 19 21 27 25 29 31  9 33
#  35 37 39 41 43 45 47 49]
# Days of study for test set: [11 14 16 18 20 22 15 17 19 23 25 27 29 31 33 35 37 39 41 45 10 21]
# Percentage of data used for training: 64.66%
# Misclassified instances in fold 15:
#     m_id  day_of_study  true_label  predicted_label
# 1   1359            14           0                1
# 9   1360            11           0                1
# 11  1360            16           0                1
# 24  1276            11           1                0
# 25  1276            15           1                0
# --------------------------------------------------
#
# Fold 16:
# Original train class distribution: Counter({0: 254, 1: 45})
# Original test class distribution: Counter({0: 62, 1: 21})
#
#
# Fold 16 results:
# Accuracy: 0.6867
# F1-macro: 0.5389
# F1-micro: 0.6867
# F1-weighted: 0.6679
# Precision: 0.3333
# Recall: 0.2381
# ROC AUC: 0.6144
# True Positives: 5, False Negatives: 16, False Positives: 10, True Negatives: 52
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.84      0.80        62
#            1       0.33      0.24      0.28        21
#
#     accuracy                           0.69        83
#    macro avg       0.55      0.54      0.54        83
# weighted avg       0.66      0.69      0.67        83
#
# Days of study for training set: [14 18 20 22 24  7 23 17 11 16 10 13 15 19 21 27 25 29 31  9 33 35 37 39
#  41 43 45 47 49]
# Days of study for test set: [10 12 14 16 18  8 20 22 24 26 11 15 17 19 23 25 27 29 31 33 35 37 39 41
#  45]
# Percentage of data used for training: 78.27%
# Misclassified instances in fold 16:
#     m_id  day_of_study  true_label  predicted_label
# 0   1260            10           0                1
# 3   1260            12           0                1
# 14  1260             8           0                1
# 16  1261            10           0                1
# 21  1261            18           0                1
# --------------------------------------------------
#
# Fold 17:
# Original train class distribution: Counter({0: 200, 1: 49})
# Original test class distribution: Counter({0: 116, 1: 17})
#
#
# Fold 17 results:
# Accuracy: 0.7293
# F1-macro: 0.4911
# F1-micro: 0.7293
# F1-weighted: 0.7503
# Precision: 0.1200
# Recall: 0.1765
# ROC AUC: 0.5137
# True Positives: 3, False Negatives: 14, False Positives: 22, True Negatives: 94
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84       116
#            1       0.12      0.18      0.14        17
#
#     accuracy                           0.73       133
#    macro avg       0.50      0.49      0.49       133
# weighted avg       0.77      0.73      0.75       133
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 11 15 17 19 25 27 29 31 33 35 37 39
#  41 45 13 21]
# Days of study for test set: [17 11 14 16 18 20 22 15 19 21 23 25 27 29 31  9 33 35 37 39 41 43 45 47
#  49]
# Percentage of data used for training: 65.18%
# Misclassified instances in fold 17:
#     m_id  day_of_study  true_label  predicted_label
# 2   1360            11           0                1
# 3   1360            14           0                1
# 4   1360            16           0                1
# 17  1285            15           1                0
# 18  1285            15           1                0
# --------------------------------------------------
#
# Fold 18:
# Original train class distribution: Counter({0: 209, 1: 58})
# Original test class distribution: Counter({0: 107, 1: 8})
#
#
# Fold 18 results:
# Accuracy: 0.8435
# F1-macro: 0.5071
# F1-micro: 0.8435
# F1-weighted: 0.8576
# Precision: 0.0833
# Recall: 0.1250
# ROC AUC: 0.8178
# True Positives: 1, False Negatives: 7, False Positives: 11, True Negatives: 96
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91       107
#            1       0.08      0.12      0.10         8
#
#     accuracy                           0.84       115
#    macro avg       0.51      0.51      0.51       115
# weighted avg       0.87      0.84      0.86       115
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 17 11 15 19 23 25 27 29 31 33 35 37 39 41
#  45 13 21  9 43 47]
# Days of study for test set: [10 14 16 18 20 22 24 26 23 11 17 19 21 25 27 29 15 31 33 35 37 39 41 43
#  45 47 49]
# Percentage of data used for training: 69.90%
# Misclassified instances in fold 18:
#     m_id  day_of_study  true_label  predicted_label
# 0   1261            10           0                1
# 5   1261            18           0                1
# 21  1382            11           1                0
# 22  1382            17           1                0
# 24  1382            21           1                0
# --------------------------------------------------
#
# Fold 19:
# Original train class distribution: Counter({0: 233, 1: 58})
# Original test class distribution: Counter({0: 83, 1: 8})
#
#
# Fold 19 results:
# Accuracy: 0.8901
# F1-macro: 0.4709
# F1-micro: 0.8901
# F1-weighted: 0.8591
# Precision: 0.0000
# Recall: 0.0000
# ROC AUC: 0.8539
# True Positives: 0, False Negatives: 8, False Positives: 2, True Negatives: 81
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94        83
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.89        91
#    macro avg       0.46      0.49      0.47        91
# weighted avg       0.83      0.89      0.86        91
#
# Days of study for training set: [14 18 20 22 24  7 10 16 26 23 17 11 15 19 25 27 29 31 33 35 37 39 41 45
#  13 21  9 43 47 49]
# Days of study for test set: [10 12 14 16 18  8 11 20 22 17 19 21 23 25 27 29 15 31 33 35 37]
# Percentage of data used for training: 76.18%
# Misclassified instances in fold 19:
#     m_id  day_of_study  true_label  predicted_label
# 14  1260             8           0                1
# 16  1359            11           0                1
# 40  1382            11           1                0
# 41  1382            17           1                0
# 42  1382            19           1                0
# --------------------------------------------------
#
# Fold 20:
# Original train class distribution: Counter({0: 211, 1: 50})
# Original test class distribution: Counter({0: 105, 1: 16})
#
#
# Fold 20 results:
# Accuracy: 0.8182
# F1-macro: 0.6039
# F1-micro: 0.8182
# F1-weighted: 0.8182
# Precision: 0.3125
# Recall: 0.3125
# ROC AUC: 0.8131
# True Positives: 5, False Negatives: 11, False Positives: 11, True Negatives: 94
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       105
#            1       0.31      0.31      0.31        16
#
#     accuracy                           0.82       121
#    macro avg       0.60      0.60      0.60       121
# weighted avg       0.82      0.82      0.82       121
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 23 17 11 15 19 25 27 29 31 33 35 37 39 41
#  45 13 21  9 43 47 49]
# Days of study for test set: [10 14 16 18 20 22 24 26 13 15 17 19 21 23 27 11 25 29 31 33 35 37 39]
# Percentage of data used for training: 68.32%
# Misclassified instances in fold 20:
#     m_id  day_of_study  true_label  predicted_label
# 0   1261            10           0                1
# 5   1261            18           0                1
# 19  1284            10           1                0
# 20  1284            13           1                0
# 21  1284            15           1                0
# --------------------------------------------------
#
# Fold 21:
# Original train class distribution: Counter({0: 237, 1: 58})
# Original test class distribution: Counter({0: 79, 1: 8})
#
#
# Fold 21 results:
# Accuracy: 0.7701
# F1-macro: 0.5744
# F1-micro: 0.7701
# F1-weighted: 0.8099
# Precision: 0.2000
# Recall: 0.5000
# ROC AUC: 0.7500
# True Positives: 4, False Negatives: 4, False Positives: 16, True Negatives: 63
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86        79
#            1       0.20      0.50      0.29         8
#
#     accuracy                           0.77        87
#    macro avg       0.57      0.65      0.57        87
# weighted avg       0.87      0.77      0.81        87
#
# Days of study for training set: [10 12 14 16 18  8 20 22 24 26 23 11 15 17 19 25 27 29 31 33 35 37 39 41
#  45 13 21  9 43 47 49]
# Days of study for test set: [14 18 20 22 24  7 17 11 16 10 13 15 19 21 23 27 25 29 31 33 35 37 39 41
#  43 45 47]
# Percentage of data used for training: 77.23%
# Misclassified instances in fold 21:
#     m_id  day_of_study  true_label  predicted_label
# 0   1258            14           0                1
# 11  1361            11           0                1
# 23  1284            10           1                0
# 24  1284            13           1                0
# 25  1284            15           1                0
# --------------------------------------------------
#
# Fold 22:
# Original train class distribution: Counter({0: 213, 1: 58})
# Original test class distribution: Counter({0: 103, 1: 8})
#
#
# Fold 22 results:
# Accuracy: 0.8559
# F1-macro: 0.5604
# F1-micro: 0.8559
# F1-weighted: 0.8688
# Precision: 0.1667
# Recall: 0.2500
# ROC AUC: 0.8313
# True Positives: 2, False Negatives: 6, False Positives: 10, True Negatives: 93
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92       103
#            1       0.17      0.25      0.20         8
#
#     accuracy                           0.86       111
#    macro avg       0.55      0.58      0.56       111
# weighted avg       0.88      0.86      0.87       111
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 17 11 15 19 23 25 27 29 31 33 35 37 39
#  41 45 13 21  9 43 47]
# Days of study for test set: [23 11 14 16 18 20 22 17 19 21 25 27 29 10 15 31 33 35 37 39 41 43 45 47
#  49]
# Percentage of data used for training: 70.94%
# Misclassified instances in fold 22:
#     m_id  day_of_study  true_label  predicted_label
# 3   1360            14           0                1
# 17  1382            11           1                0
# 18  1382            17           1                0
# 19  1382            19           1                0
# 20  1382            21           1                0
# --------------------------------------------------
#
# Fold 23:
# Original train class distribution: Counter({0: 262, 1: 46})
# Original test class distribution: Counter({0: 54, 1: 20})
#
#
# Fold 23 results:
# Accuracy: 0.6757
# F1-macro: 0.4983
# F1-micro: 0.6757
# F1-weighted: 0.6354
# Precision: 0.3000
# Recall: 0.1500
# ROC AUC: 0.6213
# True Positives: 3, False Negatives: 17, False Positives: 7, True Negatives: 47
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.87      0.80        54
#            1       0.30      0.15      0.20        20
#
#     accuracy                           0.68        74
#    macro avg       0.52      0.51      0.50        74
# weighted avg       0.62      0.68      0.64        74
#
# Days of study for training set: [10 12 14 16 18  8 20 22 24 26 23 11 15 17 19 25 27 29 31 33 35 37 39 41
#  45 21  9 43 47 49]
# Days of study for test set: [14 18 20 22 24  7 17 10 13 15 19 21 23 27 11 25 29 31 33 35 37 39]
# Percentage of data used for training: 80.63%
# Misclassified instances in fold 23:
#     m_id  day_of_study  true_label  predicted_label
# 11  1281            10           1                0
# 12  1281            13           1                0
# 13  1281            15           1                0
# 14  1281            17           1                0
# 16  1281            19           1                0
# --------------------------------------------------
#
# Fold 24:
# Original train class distribution: Counter({0: 247, 1: 58})
# Original test class distribution: Counter({0: 69, 1: 8})
#
#
# Fold 24 results:
# Accuracy: 0.7922
# F1-macro: 0.5758
# F1-micro: 0.7922
# F1-weighted: 0.8158
# Precision: 0.2143
# Recall: 0.3750
# ROC AUC: 0.8243
# True Positives: 3, False Negatives: 5, False Positives: 11, True Negatives: 58
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88        69
#            1       0.21      0.38      0.27         8
#
#     accuracy                           0.79        77
#    macro avg       0.57      0.61      0.58        77
# weighted avg       0.85      0.79      0.82        77
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 17 11 15 19 23 25 27 29 31 33 35 37 39
#  41 45 13 21  9 43 47 49]
# Days of study for test set: [23 11 14 16 18 20 22 10 13 15 17 19 21 27 25 29 31 33 35 37 39]
# Percentage of data used for training: 79.84%
# Misclassified instances in fold 24:
#     m_id  day_of_study  true_label  predicted_label
# 2   1359            11           0                1
# 13  1360            16           0                1
# 26  1284            10           1                0
# 27  1284            13           1                0
# 28  1284            15           1                0
# --------------------------------------------------
#
# Fold 25:
# Original train class distribution: Counter({0: 285, 1: 58})
# Original test class distribution: Counter({0: 31, 1: 8})
#
#
# Fold 25 results:
# Accuracy: 0.7949
# F1-macro: 0.4429
# F1-micro: 0.7949
# F1-weighted: 0.7040
# Precision: 1.0000
# Recall: 0.0000
# ROC AUC: 0.8105
# True Positives: 0, False Negatives: 8, False Positives: 0, True Negatives: 31
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.89        31
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.79        39
#    macro avg       0.40      0.50      0.44        39
# weighted avg       0.63      0.79      0.70        39
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 11 15 17 19 23 25 27 29 31 33 35 37 39
#  41 45 13 21  9 43 47 49]
# Days of study for test set: [23 17 11 14 16 18 20 22 19 21 25 27 29]
# Percentage of data used for training: 89.79%
# Misclassified instances in fold 25:
#     m_id  day_of_study  true_label  predicted_label
# 31  1382            11           1                0
# 32  1382            17           1                0
# 33  1382            19           1                0
# 34  1382            21           1                0
# 35  1382            23           1                0
# --------------------------------------------------
#
# Fold 26:
# Original train class distribution: Counter({0: 243, 1: 58})
# Original test class distribution: Counter({0: 73, 1: 8})
#
#
# Fold 26 results:
# Accuracy: 0.7531
# F1-macro: 0.4296
# F1-micro: 0.7531
# F1-weighted: 0.7743
# Precision: 0.0000
# Recall: 0.0000
# ROC AUC: 0.7723
# True Positives: 0, False Negatives: 8, False Positives: 12, True Negatives: 61
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86        73
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.75        81
#    macro avg       0.44      0.42      0.43        81
# weighted avg       0.80      0.75      0.77        81
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 17 11 15 19 23 25 27 29 31 33 35 37 39 41
#  45 13 21  9 43 47]
# Days of study for test set: [10 14 16 18 20 22 24 26 23 11 17 19 21 25 27 29 31 33 35 37 39 41 43 45
#  47 49]
# Percentage of data used for training: 78.80%
# Misclassified instances in fold 26:
#     m_id  day_of_study  true_label  predicted_label
# 0   1261            10           0                1
# 12  1261            24           0                1
# 21  1359            11           0                1
# 22  1359            14           0                1
# 30  1382            11           1                0
# --------------------------------------------------
#
# Fold 27:
# Original train class distribution: Counter({0: 243, 1: 49})
# Original test class distribution: Counter({0: 73, 1: 17})
#
#
# Fold 27 results:
# Accuracy: 0.8000
# F1-macro: 0.5339
# F1-micro: 0.8000
# F1-weighted: 0.7530
# Precision: 0.4000
# Recall: 0.1176
# ROC AUC: 0.7164
# True Positives: 2, False Negatives: 15, False Positives: 3, True Negatives: 70
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.96      0.89        73
#            1       0.40      0.12      0.18        17
#
#     accuracy                           0.80        90
#    macro avg       0.61      0.54      0.53        90
# weighted avg       0.74      0.80      0.75        90
#
# Days of study for training set: [10 12 14 16 18  8 23 11 20 22 15 17 19 25 27 29 31 33 35 37 39 41 45 13
#  21 43 47 49]
# Days of study for test set: [14 18 20 22 24  7 10 16 26 17 15 19 21 23 25 27 29 31  9 33 35 37]
# Percentage of data used for training: 76.44%
# Misclassified instances in fold 27:
#     m_id  day_of_study  true_label  predicted_label
# 0   1258            14           0                1
# 7   1258             7           0                1
# 9   1261            10           0                1
# 30  1285            15           1                0
# 31  1285            15           1                0
# --------------------------------------------------
#
# Fold 28:
# Original train class distribution: Counter({0: 209, 1: 58})
# Original test class distribution: Counter({0: 107, 1: 8})
#
#
# Fold 28 results:
# Accuracy: 0.7652
# F1-macro: 0.5451
# F1-micro: 0.7652
# F1-weighted: 0.8175
# Precision: 0.1481
# Recall: 0.5000
# ROC AUC: 0.7897
# True Positives: 4, False Negatives: 4, False Positives: 23, True Negatives: 84
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.79      0.86       107
#            1       0.15      0.50      0.23         8
#
#     accuracy                           0.77       115
#    macro avg       0.55      0.64      0.55       115
# weighted avg       0.90      0.77      0.82       115
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 17 11 15 19 25 27 29 31 33 35 37 39
#  41 45 13 21  9 43 47]
# Days of study for test set: [11 14 16 18 20 10 13 15 17 19 21 23 27 25 29 31 33 35 37 39 41 43 45 47
#  49]
# Percentage of data used for training: 69.90%
# Misclassified instances in fold 28:
#     m_id  day_of_study  true_label  predicted_label
# 0   1359            11           0                1
# 11  1361            16           0                1
# 21  1284            10           1                0
# 22  1284            13           1                0
# 23  1284            15           1                0
# --------------------------------------------------
#
# Fold 29:
# Original train class distribution: Counter({0: 243, 1: 41})
# Original test class distribution: Counter({0: 73, 1: 25})
#
#
# Fold 29 results:
# Accuracy: 0.6531
# F1-macro: 0.5018
# F1-micro: 0.6531
# F1-weighted: 0.6363
# Precision: 0.2632
# Recall: 0.2000
# ROC AUC: 0.5742
# True Positives: 5, False Negatives: 20, False Positives: 14, True Negatives: 59
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.81      0.78        73
#            1       0.26      0.20      0.23        25
#
#     accuracy                           0.65        98
#    macro avg       0.50      0.50      0.50        98
# weighted avg       0.62      0.65      0.64        98
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 17 11 15 19 23 25 27 29 31 33 35 37 39
#  41 45 13 21 43 47 49]
# Days of study for test set: [23 11 14 16 18 20 22 15 17 19 21 25 27 29 31  9 33 35 37 39 41 43 45 47]
# Percentage of data used for training: 74.35%
# Misclassified instances in fold 29:
#     m_id  day_of_study  true_label  predicted_label
# 2   1360            11           0                1
# 17  1285            15           1                0
# 18  1285            15           1                0
# 19  1285            17           1                0
# 20  1285            17           1                0
# --------------------------------------------------
#
# Fold 30:
# Original train class distribution: Counter({0: 219, 1: 45})
# Original test class distribution: Counter({0: 97, 1: 21})
#
#
# Fold 30 results:
# Accuracy: 0.7458
# F1-macro: 0.5950
# F1-micro: 0.7458
# F1-weighted: 0.7541
# Precision: 0.3200
# Recall: 0.3810
# ROC AUC: 0.7560
# True Positives: 8, False Negatives: 13, False Positives: 17, True Negatives: 80
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84        97
#            1       0.32      0.38      0.35        21
#
#     accuracy                           0.75       118
#    macro avg       0.59      0.60      0.59       118
# weighted avg       0.76      0.75      0.75       118
#
# Days of study for training set: [10 12 14 16 18  8 20 22 24 26 17 11 13 15 19 21 23 27 25 29 31  9 33 35
#  37 39 41 43 45 47]
# Days of study for test set: [14 18 20 22 24  7 23 11 15 17 19 25 27 29 31 33 35 37 39 41 45 21 43 47
#  49]
# Percentage of data used for training: 69.11%
# Misclassified instances in fold 30:
#     m_id  day_of_study  true_label  predicted_label
# 7   1258             7           0                1
# 8   1258             7           0                1
# 11  1276            11           1                0
# 12  1276            15           1                0
# 16  1276            19           1                0
# --------------------------------------------------
#
# Fold 31:
# Original train class distribution: Counter({0: 248, 1: 50})
# Original test class distribution: Counter({0: 68, 1: 16})
#
#
# Fold 31 results:
# Accuracy: 0.8214
# F1-macro: 0.6476
# F1-micro: 0.8214
# F1-weighted: 0.8008
# Precision: 0.5556
# Recall: 0.3125
# ROC AUC: 0.8107
# True Positives: 5, False Negatives: 11, False Positives: 4, True Negatives: 64
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.90        68
#            1       0.56      0.31      0.40        16
#
#     accuracy                           0.82        84
#    macro avg       0.70      0.63      0.65        84
# weighted avg       0.80      0.82      0.80        84
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 23 11 15 17 19 25 27 29 31 33 35 37 39 41
#  45 13 21  9 43 47 49]
# Days of study for test set: [10 14 16 18 20 22 24 26 17 13 15 19 21 23 27 11 25 29 31 33 35 37 39 41]
# Percentage of data used for training: 78.01%
# Misclassified instances in fold 31:
#     m_id  day_of_study  true_label  predicted_label
# 0   1261            10           0                1
# 21  1284            10           1                0
# 22  1284            13           1                0
# 23  1284            15           1                0
# 24  1284            17           1                0
# --------------------------------------------------
#
# Fold 32:
# Original train class distribution: Counter({0: 237, 1: 58})
# Original test class distribution: Counter({0: 79, 1: 8})
#
#
# Fold 32 results:
# Accuracy: 0.7931
# F1-macro: 0.5930
# F1-micro: 0.7931
# F1-weighted: 0.8259
# Precision: 0.2222
# Recall: 0.5000
# ROC AUC: 0.7896
# True Positives: 4, False Negatives: 4, False Positives: 14, True Negatives: 65
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.82      0.88        79
#            1       0.22      0.50      0.31         8
#
#     accuracy                           0.79        87
#    macro avg       0.58      0.66      0.59        87
# weighted avg       0.88      0.79      0.83        87
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 17 11 15 19 23 25 27 29 31 33 35 37 39
#  41 45 13 21  9 43 47 49]
# Days of study for test set: [23 11 14 16 18 20 10 13 15 17 19 21 27 25 29 31 33 35 37 39 41 43 45 47]
# Percentage of data used for training: 77.23%
# Misclassified instances in fold 32:
#     m_id  day_of_study  true_label  predicted_label
# 11  1361            11           0                1
# 23  1284            10           1                0
# 24  1284            13           1                0
# 25  1284            15           1                0
# 26  1284            17           1                0
# --------------------------------------------------
#
# Fold 33:
# Original train class distribution: Counter({0: 255, 1: 50})
# Original test class distribution: Counter({0: 61, 1: 16})
#
#
# Fold 33 results:
# Accuracy: 0.7532
# F1-macro: 0.5733
# F1-micro: 0.7532
# F1-weighted: 0.7353
# Precision: 0.3636
# Recall: 0.2500
# ROC AUC: 0.7787
# True Positives: 4, False Negatives: 12, False Positives: 7, True Negatives: 54
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85        61
#            1       0.36      0.25      0.30        16
#
#     accuracy                           0.75        77
#    macro avg       0.59      0.57      0.57        77
# weighted avg       0.72      0.75      0.74        77
#
# Days of study for training set: [14 18 20 22 24  7 10 16 26 17 11 15 19 23 25 27 29 31 33 35 37 39 41 45
#  13 21  9 43 47 49]
# Days of study for test set: [10 12 14 16 18  8 23 13 15 17 19 21 27 11 25 29 31 33 35 37 39]
# Percentage of data used for training: 79.84%
# Misclassified instances in fold 33:
#     m_id  day_of_study  true_label  predicted_label
# 18  1284            10           1                0
# 19  1284            13           1                0
# 20  1284            15           1                0
# 21  1284            17           1                0
# 26  1382            11           1                0
# --------------------------------------------------
#
# Fold 34:
# Original train class distribution: Counter({0: 240, 1: 49})
# Original test class distribution: Counter({0: 76, 1: 17})
#
#
# Fold 34 results:
# Accuracy: 0.6667
# F1-macro: 0.4290
# F1-micro: 0.6667
# F1-weighted: 0.6627
# Precision: 0.0625
# Recall: 0.0588
# ROC AUC: 0.4737
# True Positives: 1, False Negatives: 16, False Positives: 15, True Negatives: 61
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.80        76
#            1       0.06      0.06      0.06        17
#
#     accuracy                           0.67        93
#    macro avg       0.43      0.43      0.43        93
# weighted avg       0.66      0.67      0.66        93
#
# Days of study for training set: [10 12 14 16 18  8 20 22 24 26 17 11 15 19 23 25 27 29 31 33 35 37 39 41
#  45 13 21 43 47 49]
# Days of study for test set: [14 18 20 22 24  7 23 11 16 15 17 19 21 25 27 29 31  9 33 35 37 39 41 43
#  45 47]
# Percentage of data used for training: 75.65%
# Misclassified instances in fold 34:
#     m_id  day_of_study  true_label  predicted_label
# 0   1258            14           0                1
# 7   1258             7           0                1
# 8   1258             7           0                1
# 11  1359            11           0                1
# 12  1359            14           0                1
# --------------------------------------------------
#
# Fold 35:
# ...
#  43 45 47 49]
# Percentage of data used for training: 78.27%
# Misclassified instances in fold 38:
#     m_id  day_of_study  true_label  predicted_label
# 0   1258            14           0                1
# 8   1258             7           0                1
# 11  1281            10           1                0
# 13  1281            15           1                0
# 14  1281            17           1                0
# --------------------------------------------------
#
# Fold 39:
# Original train class distribution: Counter({0: 285, 1: 33})
# Original test class distribution: Counter({1: 33, 0: 31})
#
#
# Fold 39 results:
# Accuracy: 0.5781
# F1-macro: 0.5022
# F1-micro: 0.5781
# F1-weighted: 0.4961
# Precision: 1.0000
# Recall: 0.1818
# ROC AUC: 0.8065
# True Positives: 6, False Negatives: 27, False Positives: 0, True Negatives: 31
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.53      1.00      0.70        31
#            1       1.00      0.18      0.31        33
#
#     accuracy                           0.58        64
#    macro avg       0.77      0.59      0.50        64
# weighted avg       0.77      0.58      0.50        64
#
# Days of study for training set: [14 18 20 22 24  7 10 16 26 23 17 11 15 19 25 27 29 31 33 35 37 39 41 45
#  13 21 43 47 49]
# Days of study for test set: [10 12 14 16 18  8 11 20 22 13 15 17 19 21 23 27 25 29 31  9]
# Percentage of data used for training: 83.25%
# Misclassified instances in fold 39:
#     m_id  day_of_study  true_label  predicted_label
# 31  1284            10           1                0
# 32  1284            13           1                0
# 33  1284            15           1                0
# 34  1284            17           1                0
# 37  1284            23           1                0
# --------------------------------------------------
#
# Fold 40:
# Original train class distribution: Counter({0: 215, 1: 58})
# Original test class distribution: Counter({0: 101, 1: 8})
#
#
# Fold 40 results:
# Accuracy: 0.7890
# F1-macro: 0.5139
# F1-micro: 0.7890
# F1-weighted: 0.8259
# Precision: 0.1053
# Recall: 0.2500
# ROC AUC: 0.8255
# True Positives: 2, False Negatives: 6, False Positives: 17, True Negatives: 84
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.83      0.88       101
#            1       0.11      0.25      0.15         8
#
#     accuracy                           0.79       109
#    macro avg       0.52      0.54      0.51       109
# weighted avg       0.87      0.79      0.83       109
#
# Days of study for training set: [10 12 14 16 18  8 20 22 24 26 23 11 15 17 19 25 27 29 31 33 35 37 39 41
#  45 13 21  9 43 47]
# Days of study for test set: [14 18 20 22 24  7 17 11 19 21 23 25 27 29 31 33 35 37 39 41 43 45 47 49]
# Percentage of data used for training: 71.47%
# Misclassified instances in fold 40:
#     m_id  day_of_study  true_label  predicted_label
# 0   1258            14           0                1
# 11  1382            11           1                0
# 12  1382            17           1                0
# 13  1382            19           1                0
# 16  1382            25           1                0
# --------------------------------------------------
#
# Fold 41:
# Original train class distribution: Counter({0: 189, 1: 58})
# Original test class distribution: Counter({0: 127, 1: 8})
#
#
# Fold 41 results:
# Accuracy: 0.8370
# F1-macro: 0.5617
# F1-micro: 0.8370
# F1-weighted: 0.8679
# Precision: 0.1500
# Recall: 0.3750
# ROC AUC: 0.7864
# True Positives: 3, False Negatives: 5, False Positives: 17, True Negatives: 110
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.87      0.91       127
#            1       0.15      0.38      0.21         8
#
#     accuracy                           0.84       135
#    macro avg       0.55      0.62      0.56       135
# weighted avg       0.91      0.84      0.87       135
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 23 17 11 15 19 25 27 29 31 33 35 37 39
#  41 45 13 21  9 43 47 49]
# Days of study for test set: [11 14 16 18 20 22 17 19 21 23 25 27 29 31 33 35 37 39 41 43 45 47]
# Percentage of data used for training: 64.66%
# Misclassified instances in fold 41:
#     m_id  day_of_study  true_label  predicted_label
# 0   1359            11           0                1
# 9   1360            11           0                1
# 24  1382            11           1                0
# 25  1382            17           1                0
# 26  1382            19           1                0
# --------------------------------------------------
#
# Fold 42:
# Original train class distribution: Counter({0: 206, 1: 45})
# Original test class distribution: Counter({0: 110, 1: 21})
#
#
# Fold 42 results:
# Accuracy: 0.7405
# F1-macro: 0.6325
# F1-micro: 0.7405
# F1-weighted: 0.7678
# Precision: 0.3333
# Recall: 0.6190
# ROC AUC: 0.7978
# True Positives: 13, False Negatives: 8, False Positives: 26, True Negatives: 84
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.76      0.83       110
#            1       0.33      0.62      0.43        21
#
#     accuracy                           0.74       131
#    macro avg       0.62      0.69      0.63       131
# weighted avg       0.82      0.74      0.77       131
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 17 11 13 15 19 21 23 27 25 29 31  9 33
#  35 37 39 41 43 45 47 49]
# Days of study for test set: [23 11 14 16 15 17 19 25 27 29 31 33 35 37 39 41 45 21 43 47]
# Percentage of data used for training: 65.71%
# Misclassified instances in fold 42:
#     m_id  day_of_study  true_label  predicted_label
# 2   1359            11           0                1
# 13  1276            17           1                0
# 15  1276            19           1                0
# 16  1276            19           1                0
# 17  1276            23           1                0
# --------------------------------------------------
#
# Fold 43:
# Original train class distribution: Counter({0: 269, 1: 41})
# Original test class distribution: Counter({0: 47, 1: 25})
#
#
# Fold 43 results:
# Accuracy: 0.6250
# F1-macro: 0.4693
# F1-micro: 0.6250
# F1-weighted: 0.5571
# Precision: 0.3750
# Recall: 0.1200
# ROC AUC: 0.6400
# True Positives: 3, False Negatives: 22, False Positives: 5, True Negatives: 42
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.66      0.89      0.76        47
#            1       0.38      0.12      0.18        25
#
#     accuracy                           0.62        72
#    macro avg       0.52      0.51      0.47        72
# weighted avg       0.56      0.62      0.56        72
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 26 11 15 17 19 23 25 27 29 31 33 35 37 39
#  41 45 13 21 43 47]
# Days of study for test set: [23 17 15 19 21 25 27 29 31  9 11 33 35 37 39 41 43 45 47 49]
# Percentage of data used for training: 81.15%
# Misclassified instances in fold 43:
#    m_id  day_of_study  true_label  predicted_label
# 4  1285            15           1                0
# 5  1285            15           1                0
# 6  1285            17           1                0
# 7  1285            17           1                0
# 8  1285            19           1                0
# --------------------------------------------------
#
# Fold 44:
# Original train class distribution: Counter({0: 255, 1: 41})
# Original test class distribution: Counter({0: 61, 1: 25})
#
#
# Fold 44 results:
# Accuracy: 0.7674
# F1-macro: 0.5962
# F1-micro: 0.7674
# F1-weighted: 0.7063
# Precision: 1.0000
# Recall: 0.2000
# ROC AUC: 0.7613
# True Positives: 5, False Negatives: 20, False Positives: 0, True Negatives: 61
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86        61
#            1       1.00      0.20      0.33        25
#
#     accuracy                           0.77        86
#    macro avg       0.88      0.60      0.60        86
# weighted avg       0.82      0.77      0.71        86
#
# Days of study for training set: [14 18 20 22 24  7 10 16 26 23 11 15 17 19 25 27 29 31 33 35 37 39 41 45
#  13 21 43 47 49]
# Days of study for test set: [10 12 14 16 18  8 17 13 15 19 21 23 27 25 29 31  9 33 35 37]
# Percentage of data used for training: 77.49%
# Misclassified instances in fold 44:
#     m_id  day_of_study  true_label  predicted_label
# 18  1284            10           1                0
# 19  1284            13           1                0
# 20  1284            15           1                0
# 21  1284            17           1                0
# 26  1285            15           1                0
# --------------------------------------------------
#
# Fold 45:
# Original train class distribution: Counter({0: 237, 1: 58})
# Original test class distribution: Counter({0: 79, 1: 8})
#
#
# Fold 45 results:
# Accuracy: 0.8046
# F1-macro: 0.6274
# F1-micro: 0.8046
# F1-weighted: 0.8371
# Precision: 0.2632
# Recall: 0.6250
# ROC AUC: 0.7769
# True Positives: 5, False Negatives: 3, False Positives: 14, True Negatives: 65
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.82      0.88        79
#            1       0.26      0.62      0.37         8
#
#     accuracy                           0.80        87
#    macro avg       0.61      0.72      0.63        87
# weighted avg       0.89      0.80      0.84        87
#
# Days of study for training set: [14 18 20 22 24  7 10 12 16  8 17 11 15 19 23 25 27 29 31 33 35 37 39 41
#  45 13 21  9 43 47 49]
# Days of study for test set: [10 14 16 18 20 22 24 26 23 11 13 15 17 19 21 27 25 29 31 33 35 37 39]
# Percentage of data used for training: 77.23%
# Misclassified instances in fold 45:
#     m_id  day_of_study  true_label  predicted_label
# 0   1261            10           0                1
# 5   1261            18           0                1
# 23  1360            16           0                1
# 36  1284            10           1                0
# 37  1284            13           1                0
# --------------------------------------------------
#
# Fold 46:
# Original train class distribution: Counter({0: 290, 1: 33})
# Original test class distribution: Counter({1: 33, 0: 26})
#
#
# Fold 46 results:
# Accuracy: 0.5424
# F1-macro: 0.4954
# F1-micro: 0.5424
# F1-weighted: 0.4771
# Precision: 0.8750
# Recall: 0.2121
# ROC AUC: 0.7424
# True Positives: 7, False Negatives: 26, False Positives: 1, True Negatives: 25
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.49      0.96      0.65        26
#            1       0.88      0.21      0.34        33
#
#     accuracy                           0.54        59
#    macro avg       0.68      0.59      0.50        59
# weighted avg       0.71      0.54      0.48        59
#
# Days of study for training set: [10 12 14 16 18  8 20 22 24 26 17 11 13 15 19 21 23 27 25 29 31  9 33 35
#  37 39 41 43 45 47 49]
# Days of study for test set: [14 18 20 22 24  7 23 11 16 15 17 19 25 27 29 31 33 35 37 39 41 45 10 13
#  21]
# Percentage of data used for training: 84.55%
# Misclassified instances in fold 46:
#     m_id  day_of_study  true_label  predicted_label
# 12  1360            14           0                1
# 26  1276            11           1                0
# 28  1276            17           1                0
# 29  1276            17           1                0
# 31  1276            19           1                0
# --------------------------------------------------
#
# Fold 47:
# Original train class distribution: Counter({0: 234, 1: 41})
# Original test class distribution: Counter({0: 82, 1: 25})
#
#
# Fold 47 results:
# Accuracy: 0.7850
# F1-macro: 0.5662
# F1-micro: 0.7850
# F1-weighted: 0.7303
# Precision: 0.6667
# Recall: 0.1600
# ROC AUC: 0.7976
# True Positives: 4, False Negatives: 21, False Positives: 2, True Negatives: 80
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.98      0.87        82
#            1       0.67      0.16      0.26        25
#
#     accuracy                           0.79       107
#    macro avg       0.73      0.57      0.57       107
# weighted avg       0.76      0.79      0.73       107
#
# Days of study for training set: [14 18 20 22 24  7 23 17 11 16 15 19 25 27 29 31 33 35 37 39 41 45 10 13
#  21 43 47 49]
# Days of study for test set: [10 12 14 16 18  8 20 22 24 26 15 17 19 21 23 25 27 29 31  9 11 33 35 37
#  39 41]
# Percentage of data used for training: 71.99%
# Misclassified instances in fold 47:
#     m_id  day_of_study  true_label  predicted_label
# 16  1261            10           0                1
# 35  1285            15           1                0
# 36  1285            15           1                0
# 37  1285            17           1                0
# 38  1285            17           1                0
# --------------------------------------------------
#
# Fold 48:
# Original train class distribution: Counter({0: 197, 1: 33})
# Original test class distribution: Counter({0: 119, 1: 33})
#
#
# Fold 48 results:
# Accuracy: 0.7434
# F1-macro: 0.5544
# F1-micro: 0.7434
# F1-weighted: 0.7186
# Precision: 0.3500
# Recall: 0.2121
# ROC AUC: 0.7153
# True Positives: 7, False Negatives: 26, False Positives: 13, True Negatives: 106
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84       119
#            1       0.35      0.21      0.26        33
#
#     accuracy                           0.74       152
#    macro avg       0.58      0.55      0.55       152
# weighted avg       0.70      0.74      0.72       152
#
# Days of study for training set: [14 18 20 22 24  7 10 16 26 23 17 11 13 15 19 21 27 25 29 31  9 33 35 37
#  39 41 43 45 47 49]
# Days of study for test set: [10 12 14 16 18  8 11 15 17 19 23 25 27 29 31 33 35 37 39 41 45 13 21 43
#  47 20 22]
# Percentage of data used for training: 60.21%
# Misclassified instances in fold 48:
#     m_id  day_of_study  true_label  predicted_label
# 3   1260            12           0                1
# 10  1260            16           0                1
# 16  1276            11           1                0
# 18  1276            17           1                0
# 19  1276            17           1                0
# --------------------------------------------------
#
# Fold 49:
# Original train class distribution: Counter({0: 222, 1: 45})
# Original test class distribution: Counter({0: 94, 1: 21})
#
#
# Fold 49 results:
# Accuracy: 0.7478
# F1-macro: 0.5330
# F1-micro: 0.7478
# F1-weighted: 0.7341
# Precision: 0.2500
# Recall: 0.1905
# ROC AUC: 0.7325
# True Positives: 4, False Negatives: 17, False Positives: 12, True Negatives: 82
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85        94
#            1       0.25      0.19      0.22        21
#
#     accuracy                           0.75       115
#    macro avg       0.54      0.53      0.53       115
# weighted avg       0.72      0.75      0.73       115
#
# Days of study for training set: [14 18 20 22 24  7 23 17 11 16 10 13 15 19 21 27 25 29 31  9 33 35 37 39
#  41 43 45 47 49]
# Days of study for test set: [10 12 14 16 18  8 20 22 24 26 11 15 17 19 23 25 27 29 31 33 35 37 39 41
#  45 21]
# Percentage of data used for training: 69.90%
# Misclassified instances in fold 49:
#     m_id  day_of_study  true_label  predicted_label
# 3   1260            12           0                1
# 14  1260             8           0                1
# 16  1261            10           0                1
# 21  1261            18           0                1
# 25  1261            22           0                1
# --------------------------------------------------
#
# All Folds Completed.
#
# --------------------------------------------------
#
# Summary of Results:
#
#
# Summary Across Folds:
# Mean accuracy: 0.7518
# Mean F1-macro: 0.5493
# Mean F1-micro: 0.7518
# Mean F1-weighted: 0.7399
# Mean precision: 0.3636
# Mean recall: 0.2758
# Mean ROC AUC: 0.7444
#
# Standard Deviation of F1-macro: 0.0607
# Variance of F1-macro: 0.0037
# Coefficient of Variation of F1-macro: 0.1106
# Dispersion Index of F1-macro: 0.0067
#
# --------------------------------------------------

# %%
# Ensure output directory exists
if not os.path.exists(f"{OUTPUT_DIR}/{split_method}/top_features"):
    os.makedirs(f"{OUTPUT_DIR}/{split_method}/top_features")

# List to store all fold data
all_folds_data = []

# Read and combine feature importances from all folds
for fold in m_data.keys():
    # Load the feature importance file for the current fold
    fold_file = f"{OUTPUT_DIR}/{split_method}/fold_{fold}/top_features.csv"
    if os.path.exists(fold_file):
        fold_data = pd.read_csv(fold_file)
        fold_data['fold'] = fold  # Add fold number for tracking
        all_folds_data.append(fold_data)
    else:
        print(f"File not found for fold {fold}: {fold_file}")

# Combine all fold data into one DataFrame
combined_data = pd.concat(all_folds_data, ignore_index=True)

# Pivot data to include importance per fold as separate columns
importance_per_fold = combined_data.pivot_table(
    index='feature',
    columns='fold',
    values='importance',
    aggfunc='first'
).reset_index()

# Rename fold columns for clarity
importance_per_fold.columns = ['feature'] + [f'Fold_{col}_importance' for col in importance_per_fold.columns if isinstance(col, int)]

# Calculate aggregate metrics for each feature
metrics = combined_data.groupby('feature')['importance'].agg(
    mean_importance='mean',
    std_importance='std'
).reset_index()

# Add variance and coefficient of variation (CV)
metrics['variance'] = metrics['std_importance'] ** 2
metrics['cv'] = metrics['std_importance'] / metrics['mean_importance']

# Merge the fold-level importances with the aggregate metrics
final_table = importance_per_fold.merge(metrics, on='feature', how='left')

# Save the final table to a CSV file
output_file = f"{OUTPUT_DIR}/{split_method}/top_features/aggregated_features_with_folds.csv"
final_table.to_csv(output_file, index=False)

print(f"Aggregated feature importances (including per fold) saved to {output_file}")
# Out:
# Aggregated feature importances (including per fold) saved to output/split_population_informed_combinations/top_features/aggregated_features_with_folds.csv

# %%
# Configuración inicial
TOP_N = 15  # Número de features para la lista corta
CV_THRESHOLD = 1.5 # Umbral para el Coefficient of Variation

# Leer la tabla de features agregadas
aggregated_file = f"{OUTPUT_DIR}/{split_method}/top_features/aggregated_features_with_folds.csv"
features_table = pd.read_csv(aggregated_file)

# Ordenar por Mean Importance
features_table = features_table.sort_values(by="mean_importance", ascending=False)

# Filtrar features consistentes (baja variabilidad)
consistent_features = features_table[features_table['cv'] <= CV_THRESHOLD]

# Generar la lista corta (Top N)
top_features = consistent_features.head(TOP_N)

# Guardar resultados
output_short = f"{OUTPUT_DIR}/{split_method}/top_features/top_{TOP_N}_features.csv"
output_full = f"{OUTPUT_DIR}/{split_method}/top_features/consistent_features.csv"

top_features.to_csv(output_short, index=False)
consistent_features.to_csv(output_full, index=False)

print(f"Top {TOP_N} features saved to: {output_short}")
print(f"Consistent features saved to: {output_full}")
# Out:
# Top 15 features saved to: output/split_population_informed_combinations/top_features/top_15_features.csv
# Consistent features saved to: output/split_population_informed_combinations/top_features/consistent_features.csv

# %%
# Read the top features
top_features = pd.read_csv(f"{OUTPUT_DIR}/{split_method}/top_features/top_{TOP_N}_features.csv")

# Prepare data for heatmap: Extract importance values for the top features
heatmap_data = []

for feature in top_features['feature']:
    importance_values = features_table[features_table['feature'] == feature].iloc[:, 1:-4].values.flatten()
    heatmap_data.append(importance_values)

# Convert to DataFrame for better handling
heatmap_df = pd.DataFrame(heatmap_data, columns=[f"Fold_{i}" for i in range(len(importance_values))], index=top_features['feature'].str.split('_').str[-1])

# Plot heatmap 
plt.figure(figsize=(20, 20))  # Ajustar tamaño de la figura
sns.heatmap(heatmap_df, 
            annot=True, 
            cmap="YlGnBu", 
            cbar_kws={'label': 'Importance'}, 
            fmt='.4f', 
            annot_kws={"size": 6})  # Tamaño de texto más pequeño

# Ajustar etiquetas del eje Y
plt.yticks(rotation=0, fontsize=8)  # Etiquetas de Y horizontales
plt.xticks(rotation=45, fontsize=8, ha='right')  # Inclinación de etiquetas de X

# Ajustar título y etiquetas
plt.title("Feature Importance Evolution Across Folds (Heatmap)", fontsize=12)
plt.xlabel("Fold", fontsize=10)
plt.ylabel("Feature", fontsize=10)

plt.tight_layout()  # Ajuste automático de márgenes
plt.show()
